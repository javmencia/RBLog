# %% [markdown]
# <a href="https://colab.research.google.com/github/javmencia/RBLog/blob/main/HIVEpcSurvival.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

print("Step 0: Setting up environment...")

# Manual 3D array creation function
def create_3d_array(matrix_list):
    if len(matrix_list) == 0:
        raise ValueError("No matrices provided")

    # Get dimensions from first matrix
    n_samples = len(matrix_list)
    n_timesteps = matrix_list[0].shape[0]
    n_features = matrix_list[0].shape[1]

    # Create empty 3D array
    array_3d = np.zeros((n_samples, n_timesteps, n_features))

    # Fill array
    for i in range(n_samples):
        array_3d[i, :, :] = matrix_list[i]

    return array_3d

print("Environment setup complete!")

# Load the data
print("Loading pcdata.csv...")
try:
    sequential_data = pd.read_csv('pcdata.csv')
    print(f"Data loaded successfully! Shape: {sequential_data.shape}")
    print(f"Columns: {sequential_data.columns.tolist()}")
except FileNotFoundError:
    print("ERROR: pcdata.csv file not found. Please ensure the file is in your working directory.")
    exit()
# Out:
# Step 0: Setting up environment...
# Environment setup complete!
# Loading pcdata.csv...
# Data loaded successfully! Shape: (8121, 101)
# Columns: ['Unnamed: 0', 'RPT', 'RINVSITE', 'STUDY', 'SEXN', 'SEX', 'RACEPRIM', 'INFCDAY', 'AGE', 'VISIT', 'VISNAME', 'DOV_ND', 'VISDAY', 'ECOGGRN', 'ECOGGR', 'STATUSN', 'STATUS', 'CONTDAY', 'LKDAY', 'DSCAUSEN', 'DSCAUSE', 'DSREAS', 'DSDECOD', 'DSBODSYS', 'DSMODIFY', 'LLTCD', 'LLTNMD', 'HLTNMD', 'HLGTNMD', 'PTCDD', 'DICTVER', 'DSDAY', 'HEIGHT', 'HEIGHTU', 'WEIGHT', 'WEIGHTU', 'BMI', 'TEMP', 'TEMPU', 'SYSBP', 'DIABP', 'DIABPU', 'PULSE', 'PULSEU', 'VTDAY', 'EXDOSENN', 'EXDOSEN', 'EXDOSE2N', 'EXDOSE2', 'EXDOSE3N', 'EXDOSE3', 'REGION', 'ENROLLDAY', 'PKSAMPN', 'PKSAMP', 'TYPEPKN', 'TYPEPK', 'PKDAY', 'TARGETQN', 'TARGETQ', 'NONTARQN', 'NONTARQ', 'cycle_number', 'total_cycles', 'anytarget', 'anynontarget', 'os_event', 'CANCDEAD', 'visit_sequence', 'total_ae_events', 'serious_ae_count', 'grade3_plus_count', 'any_grade3_plus', 'total_body_systems', 'body_systems_list', 'treatment_related_count', 'other_treatment_related_count', 'any_treatment_related', 'drug_interrupted', 'drug_reduced', 'drug_withdrawn', 'drug_not_changed', 'other_drug_interrupted', 'other_drug_reduced', 'other_drug_withdrawn', 'concomitant_treatment_given', 'grade1_count', 'grade2_count', 'grade3_count', 'grade4_count', 'grade5_count', 'ongoing_ae_count', 'mean_ae_duration', 'max_ae_duration', 'most_recent_ae_term', 'most_recent_ae_severity', 'cum_any_grade3_plus', 'cum_any_treatment_related', 'cum_drug_withdrawn', 'cum_other_drug_withdrawn', 'cum_concomitant_treatment']

# %%
print("\nStep 1: Preparing LSTM data...")

def prepare_lstm_manual(data, sequence_length=3):
    # Select features that are likely to be numeric
    feature_cols = ['ECOGGRN', 'total_ae_events', 'serious_ae_count',
                   'grade3_plus_count', 'AGE', 'VISIT', 'EXDOSENN', 'EXDOSE2N', 'EXDOSE3N', 'PKSAMPN', 'TYPEPKN', 'TARGETQN', 'NONTARQN', 'total_ae_events', 'serious_ae_count', 'grade3_plus_count', 'total_body_systems', 'treatment_related_count', 'other_treatment_related_count', 'any_treatment_related', 'drug_interrupted', 'drug_reduced', 'drug_withdrawn', 'drug_not_changed', 'other_drug_interrupted', 'other_drug_reduced', 'other_drug_withdrawn', 'concomitant_treatment_given', 'grade1_count', 'grade2_count', 'grade3_count', 'grade4_count', 'grade5_count', 'ongoing_ae_count', 'mean_ae_duration', 'max_ae_duration', 'most_recent_ae_term', 'most_recent_ae_severity', 'cum_any_grade3_plus', 'cum_any_treatment_related', 'cum_drug_withdrawn', 'cum_other_drug_withdrawn', 'cum_concomitant_treatment']

    # Check which feature columns exist in the data
    available_features = [col for col in feature_cols if col in data.columns]
    print(f"Available features: {available_features}")

    # Prepare data
    data_prep = data.copy()

    # Create outcome variable (assuming CANCDEAD exists)
    if 'CANCDEAD' in data_prep.columns:
        data_prep['outcome'] = data_prep['CANCDEAD'].astype(int) - 1
    else:
        print("WARNING: CANCDEAD column not found. Creating dummy outcome.")
        data_prep['outcome'] = 0

    # Group by patient and count visits
    visit_counts = data_prep.groupby('RPT').size()
    valid_patients = visit_counts[visit_counts >= sequence_length].index

    data_prep = data_prep[data_prep['RPT'].isin(valid_patients)]

    # Convert features to numeric and fill NaN
    for col in available_features:
        data_prep[col] = pd.to_numeric(data_prep[col], errors='coerce')

    data_prep[available_features] = data_prep[available_features].fillna(0)

    patients = data_prep['RPT'].unique()
    sequences = []
    labels = []

    print(f"Processing {len(patients)} patients with sufficient visits...")

    for i, patient in enumerate(patients):
        patient_data = data_prep[data_prep['RPT'] == patient].sort_values('VISDAY')

        if len(patient_data) >= sequence_length:
            # Get the outcome (assuming it's constant per patient)
            patient_outcome = patient_data['outcome'].iloc[0]

            # Extract features as matrix
            feature_matrix = patient_data[available_features].values

            # Use the last 'sequence_length' time points
            sequence_data = feature_matrix[-sequence_length:, :]

            sequences.append(sequence_data)
            labels.append(patient_outcome)

        # Progress indicator
        if (i + 1) % 50 == 0:
            print(f"Processed {i + 1} patients...")

    print(f"Created {len(sequences)} sequences total")

    if len(sequences) == 0:
        raise ValueError("No sequences were created. Possible issues:\n"
                        f"- Not enough patients with {sequence_length} visits\n"
                        "- Feature columns may contain non-numeric data\n"
                        "- Check if CANCDEAD variable exists and has values")

    # Create 3D array using our manual function
    sequences_array = create_3d_array(sequences)

    return {
        'sequences': sequences_array,
        'labels': np.array(labels)
    }

# Prepare the data
try:
    lstm_data = prepare_lstm_manual(sequential_data, sequence_length=3)
    print("SUCCESS: LSTM data prepared!")
    print(f"Sequences dimension: {lstm_data['sequences'].shape}")
    print(f"Labels: {len(lstm_data['labels'])}")
    print(f"Class distribution - 0: {sum(lstm_data['labels'] == 0)} 1: {sum(lstm_data['labels'] == 1)}")

except Exception as e:
    print(f"ERROR in data preparation: {e}")

    # Diagnostic information
    print("\nDIAGNOSTIC INFORMATION:")
    print(f"Number of patients: {sequential_data['RPT'].nunique()}")
    print(f"Variables in sequential_data: {sequential_data.columns.tolist()}")
    if 'CANCDEAD' in sequential_data.columns:
        print(f"CANCDEAD values:\n{sequential_data['CANCDEAD'].value_counts()}")

    visit_counts = sequential_data.groupby('RPT').size()
    print("Visit counts summary:")
    print(visit_counts.describe())

print("\nStep 2: Normalizing data...")

def normalize_3d_manual(array_3d):
    dims = array_3d.shape
    print(f"Normalizing array with dimensions: {dims}")

    # Normalize each feature across all samples and timesteps
    for feature_idx in range(dims[2]):
        feature_data = array_3d[:, :, feature_idx]
        mean_val = np.mean(feature_data)
        sd_val = np.std(feature_data)

        if sd_val > 0:
            array_3d[:, :, feature_idx] = (feature_data - mean_val) / sd_val
        # If sd = 0, leave as is (constant feature)

    array_3d = np.nan_to_num(array_3d)
    return array_3d

if 'lstm_data' in locals():
    X_sequences = normalize_3d_manual(lstm_data['sequences'].copy())
    y = lstm_data['labels']

    print("Normalization completed!")
    print(f"Data range: [{X_sequences.min():.3f}, {X_sequences.max():.3f}]")
else:
    print("Cannot normalize - lstm_data not created")

print("\nStep 3: Creating train-test split...")

if 'X_sequences' in locals() and 'y' in locals():
    # Check if we have enough samples
    if len(y) < 10:
        print(f"Warning: Only {len(y)} samples available. Using 80% for training.")
        test_size = 0.2
    else:
        test_size = 0.3

    # Create stratified split
    X_train, X_test, y_train, y_test = train_test_split(
        X_sequences, y,
        test_size=test_size,
        random_state=123,
        stratify=y
    )

    print("Training set:")
    print(f"  Sequences: {X_train.shape}")
    print(f"  Labels: {len(y_train)} (0: {sum(y_train == 0)} 1: {sum(y_train == 1)})")

    print("Test set:")
    print(f"  Sequences: {X_test.shape}")
    print(f"  Labels: {len(y_test)} (0: {sum(y_test == 0)} 1: {sum(y_test == 1)})")
else:
    print("Cannot create split - data not available")

print("\nStep 4: Building LSTM model...")

def build_lstm_model_simple(sequence_length, n_features):
    # Simple LSTM model
    model = Sequential([
        LSTM(32, input_shape=(sequence_length, n_features), return_sequences=False),
        Dropout(0.3),
        Dense(16, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])

    # Compile model
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(learning_rate=0.001),
        metrics=['accuracy', 'AUC']
    )

    return model

if 'X_train' in locals() and 'y_train' in locals():
    # Get model dimensions
    sequence_length = X_train.shape[1]
    n_features = X_train.shape[2]

    print("Building model for:")
    print(f"  Sequence length: {sequence_length}")
    print(f"  Features: {n_features}")
    print(f"  Training samples: {X_train.shape[0]}")

    # Build model
    lstm_model = build_lstm_model_simple(sequence_length, n_features)

    print("Model architecture:")
    lstm_model.summary()

    print("\nStep 5: Training LSTM model...")

    early_stopping = EarlyStopping(
        patience=10,
        restore_best_weights=True,
        monitor='val_loss'
    )

    history = lstm_model.fit(
        x=X_train,
        y=y_train,
        epochs=50,
        batch_size=32,
        validation_split=0.2,
        verbose=1,
        callbacks=[early_stopping]
    )

    print("Training completed!")

else:
    print("Cannot build model - training data not available")

print("\nStep 6: Evaluating LSTM model...")

if 'lstm_model' in locals() and 'X_test' in locals() and 'y_test' in locals():
    # Make predictions
    predictions = lstm_model.predict(X_test)
    predicted_probs = predictions.flatten()

    # Convert to binary predictions
    predicted_classes = (predicted_probs > 0.5).astype(int)

    # Calculate metrics
    conf_matrix = confusion_matrix(y_test, predicted_classes)
    accuracy = np.sum(np.diag(conf_matrix)) / np.sum(conf_matrix)

    tn, fp, fn, tp = conf_matrix.ravel()
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0

    # AUC
    if len(np.unique(y_test)) > 1:
        auc_val = roc_auc_score(y_test, predicted_probs)
    else:
        auc_val = np.nan

    # Print results
    print("=" * 50)
    print("LSTM MODEL PERFORMANCE")
    print("=" * 50)
    print(f"Accuracy:    {accuracy:.3f}")
    print(f"Sensitivity: {sensitivity:.3f}")
    print(f"Specificity: {specificity:.3f}")
    print(f"AUC:         {auc_val:.3f}")
    print(f"\nConfusion Matrix:")
    print(conf_matrix)
    print(f"\nClassification Report:")
    print(classification_report(y_test, predicted_classes))

    # Plot results if we have AUC
    if not np.isnan(auc_val):
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

        # ROC curve
        fpr, tpr, _ = roc_curve(y_test, predicted_probs)
        ax1.plot(fpr, tpr, 'b-', linewidth=2, label=f'AUC = {auc_val:.3f}')
        ax1.plot([0, 1], [0, 1], 'k--', linewidth=1)
        ax1.set_xlabel('False Positive Rate')
        ax1.set_ylabel('True Positive Rate')
        ax1.set_title('ROC Curve')
        ax1.legend()
        ax1.grid(True)

        # Training history
        if 'history' in locals():
            ax2.plot(history.history['loss'], 'b-', label='Train')
            if 'val_loss' in history.history:
                ax2.plot(history.history['val_loss'], 'r-', label='Validation')
            ax2.set_xlabel('Epoch')
            ax2.set_ylabel('Loss')
            ax2.set_title('Training Loss')
            ax2.legend()
            ax2.grid(True)

        plt.tight_layout()
        plt.show()

else:
    print("Cannot evaluate - model or test data not available")
# Out:
# Step 1: Preparing LSTM data...
# Available features: ['ECOGGRN', 'total_ae_events', 'serious_ae_count', 'grade3_plus_count', 'AGE', 'VISIT', 'EXDOSENN', 'EXDOSE2N', 'EXDOSE3N', 'PKSAMPN', 'TYPEPKN', 'TARGETQN', 'NONTARQN', 'total_ae_events', 'serious_ae_count', 'grade3_plus_count', 'total_body_systems', 'treatment_related_count', 'other_treatment_related_count', 'any_treatment_related', 'drug_interrupted', 'drug_reduced', 'drug_withdrawn', 'drug_not_changed', 'other_drug_interrupted', 'other_drug_reduced', 'other_drug_withdrawn', 'concomitant_treatment_given', 'grade1_count', 'grade2_count', 'grade3_count', 'grade4_count', 'grade5_count', 'ongoing_ae_count', 'mean_ae_duration', 'max_ae_duration', 'most_recent_ae_term', 'most_recent_ae_severity', 'cum_any_grade3_plus', 'cum_any_treatment_related', 'cum_drug_withdrawn', 'cum_other_drug_withdrawn', 'cum_concomitant_treatment']
# ERROR in data preparation: Columns must be same length as key
#
# DIAGNOSTIC INFORMATION:
# Number of patients: 526
# Variables in sequential_data: ['Unnamed: 0', 'RPT', 'RINVSITE', 'STUDY', 'SEXN', 'SEX', 'RACEPRIM', 'INFCDAY', 'AGE', 'VISIT', 'VISNAME', 'DOV_ND', 'VISDAY', 'ECOGGRN', 'ECOGGR', 'STATUSN', 'STATUS', 'CONTDAY', 'LKDAY', 'DSCAUSEN', 'DSCAUSE', 'DSREAS', 'DSDECOD', 'DSBODSYS', 'DSMODIFY', 'LLTCD', 'LLTNMD', 'HLTNMD', 'HLGTNMD', 'PTCDD', 'DICTVER', 'DSDAY', 'HEIGHT', 'HEIGHTU', 'WEIGHT', 'WEIGHTU', 'BMI', 'TEMP', 'TEMPU', 'SYSBP', 'DIABP', 'DIABPU', 'PULSE', 'PULSEU', 'VTDAY', 'EXDOSENN', 'EXDOSEN', 'EXDOSE2N', 'EXDOSE2', 'EXDOSE3N', 'EXDOSE3', 'REGION', 'ENROLLDAY', 'PKSAMPN', 'PKSAMP', 'TYPEPKN', 'TYPEPK', 'PKDAY', 'TARGETQN', 'TARGETQ', 'NONTARQN', 'NONTARQ', 'cycle_number', 'total_cycles', 'anytarget', 'anynontarget', 'os_event', 'CANCDEAD', 'visit_sequence', 'total_ae_events', 'serious_ae_count', 'grade3_plus_count', 'any_grade3_plus', 'total_body_systems', 'body_systems_list', 'treatment_related_count', 'other_treatment_related_count', 'any_treatment_related', 'drug_interrupted', 'drug_reduced', 'drug_withdrawn', 'drug_not_changed', 'other_drug_interrupted', 'other_drug_reduced', 'other_drug_withdrawn', 'concomitant_treatment_given', 'grade1_count', 'grade2_count', 'grade3_count', 'grade4_count', 'grade5_count', 'ongoing_ae_count', 'mean_ae_duration', 'max_ae_duration', 'most_recent_ae_term', 'most_recent_ae_severity', 'cum_any_grade3_plus', 'cum_any_treatment_related', 'cum_drug_withdrawn', 'cum_other_drug_withdrawn', 'cum_concomitant_treatment']
# CANCDEAD values:
# CANCDEAD
# 0    7051
# 1    1070
# Name: count, dtype: int64
# Visit counts summary:
# count    526.000000
# mean      15.439163
# std        6.940777
# min        2.000000
# 25%       10.000000
# 50%       14.000000
# 75%       19.000000
# max       48.000000
# dtype: float64
#
# Step 2: Normalizing data...
# Normalizing array with dimensions: (525, 3, 7)
# Normalization completed!
# Data range: [-2.802, 8.036]
#
# Step 3: Creating train-test split...
# Training set:
#   Sequences: (367, 3, 7)
#   Labels: 367 (0: 53 1: 0)
# Test set:
#   Sequences: (158, 3, 7)
#   Labels: 158 (0: 23 1: 0)
#
# Step 4: Building LSTM model...
# Building model for:
#   Sequence length: 3
#   Features: 7
#   Training samples: 367
# Model architecture:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 32)             │         5,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,665 (22.13 KB)
#  Trainable params: 5,665 (22.13 KB)
#  Non-trainable params: 0 (0.00 B)
# Step 5: Training LSTM model...
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - AUC: 0.4808 - accuracy: 0.0893 - loss: 0.6970 - val_AUC: 0.4375 - val_accuracy: 0.0541 - val_loss: 0.5388
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.5049 - accuracy: 0.1313 - loss: 0.5028 - val_AUC: 0.4461 - val_accuracy: 0.0811 - val_loss: 0.3631
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.4612 - accuracy: 0.1524 - loss: 0.3546 - val_AUC: 0.4571 - val_accuracy: 0.0811 - val_loss: 0.1862
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.4037 - accuracy: 0.1665 - loss: 0.1767 - val_AUC: 0.4816 - val_accuracy: 0.0811 - val_loss: -0.0104
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.4729 - accuracy: 0.1661 - loss: -0.0227 - val_AUC: 0.4877 - val_accuracy: 0.0811 - val_loss: -0.2368
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.4551 - accuracy: 0.1429 - loss: -0.2353 - val_AUC: 0.4963 - val_accuracy: 0.0811 - val_loss: -0.5202
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.4207 - accuracy: 0.1544 - loss: -0.5990 - val_AUC: 0.5208 - val_accuracy: 0.0811 - val_loss: -0.8890
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.4538 - accuracy: 0.1467 - loss: -0.9123 - val_AUC: 0.5343 - val_accuracy: 0.0811 - val_loss: -1.3491
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.3605 - accuracy: 0.1593 - loss: -1.6319 - val_AUC: 0.5245 - val_accuracy: 0.0811 - val_loss: -1.9603
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5221 - accuracy: 0.1550 - loss: -2.0469 - val_AUC: 0.5208 - val_accuracy: 0.0811 - val_loss: -2.7309
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.4086 - accuracy: 0.1781 - loss: -2.9929 - val_AUC: 0.5257 - val_accuracy: 0.0811 - val_loss: -3.7730
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.4579 - accuracy: 0.1812 - loss: -3.8850 - val_AUC: 0.5159 - val_accuracy: 0.0811 - val_loss: -5.0903
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.4159 - accuracy: 0.1685 - loss: -5.5654 - val_AUC: 0.5110 - val_accuracy: 0.0811 - val_loss: -6.7706
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.4907 - accuracy: 0.1635 - loss: -6.9569 - val_AUC: 0.4865 - val_accuracy: 0.0811 - val_loss: -8.8263
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.4752 - accuracy: 0.1638 - loss: -9.8637 - val_AUC: 0.4559 - val_accuracy: 0.0811 - val_loss: -11.2488
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.4759 - accuracy: 0.1495 - loss: -10.7213 - val_AUC: 0.4449 - val_accuracy: 0.0811 - val_loss: -13.9537
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.4522 - accuracy: 0.1570 - loss: -14.6503 - val_AUC: 0.4240 - val_accuracy: 0.0811 - val_loss: -16.9354
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.4779 - accuracy: 0.1632 - loss: -17.0648 - val_AUC: 0.4093 - val_accuracy: 0.0811 - val_loss: -20.1613
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.4695 - accuracy: 0.1525 - loss: -21.2652 - val_AUC: 0.3971 - val_accuracy: 0.0811 - val_loss: -23.6457
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.4210 - accuracy: 0.1642 - loss: -24.2359 - val_AUC: 0.5221 - val_accuracy: 0.0811 - val_loss: -27.5285
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.4976 - accuracy: 0.1516 - loss: -29.6297 - val_AUC: 0.5074 - val_accuracy: 0.0811 - val_loss: -31.8520
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5018 - accuracy: 0.1773 - loss: -30.6955 - val_AUC: 0.5074 - val_accuracy: 0.0811 - val_loss: -36.4006
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.4944 - accuracy: 0.1960 - loss: -34.1255 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -41.3917
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.4835 - accuracy: 0.1447 - loss: -41.3656 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -46.6793
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.4860 - accuracy: 0.1627 - loss: -46.3573 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -52.4369
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5050 - accuracy: 0.1408 - loss: -52.4523 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -58.5435
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1521 - loss: -57.1611 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -64.6723
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - AUC: 0.5000 - accuracy: 0.1716 - loss: -62.9250 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -70.9002
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1741 - loss: -67.1745 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -77.0218
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1546 - loss: -76.4588 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -83.1438
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1740 - loss: -77.4085 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -89.1456
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1791 - loss: -83.9809 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -94.9092
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1755 - loss: -85.6613 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -100.5585
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.5000 - accuracy: 0.1573 - loss: -91.5854 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -106.3577
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.5000 - accuracy: 0.1569 - loss: -104.0634 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -112.3610
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1583 - loss: -102.4777 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -118.2800
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1530 - loss: -107.9849 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -124.3232
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1434 - loss: -117.0915 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -130.5043
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1496 - loss: -121.3560 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -136.7067
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1590 - loss: -123.3783 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -143.0108
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1580 - loss: -127.2458 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -149.2410
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1578 - loss: -136.0634 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -155.4879
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5016 - accuracy: 0.1763 - loss: -135.2469 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -161.7589
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1560 - loss: -153.0493 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -168.3723
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.5000 - accuracy: 0.1677 - loss: -153.2355 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -175.2051
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.5000 - accuracy: 0.1506 - loss: -166.1128 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -182.1302
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1486 - loss: -166.4385 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -188.9695
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1590 - loss: -180.6401 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -195.8900
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.5000 - accuracy: 0.1430 - loss: -184.7399 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -203.0006
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.5000 - accuracy: 0.1414 - loss: -186.3674 - val_AUC: 0.5000 - val_accuracy: 0.0811 - val_loss: -210.0152
# Training completed!
#
# Step 6: Evaluating LSTM model...
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# ==================================================
# LSTM MODEL PERFORMANCE
# ==================================================
# Accuracy:    0.146
# Sensitivity: 1.000
# Specificity: 0.000
# AUC:         0.500
#
# Confusion Matrix:
# [[  0 135]
#  [  0  23]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00       135
#            0       0.15      1.00      0.25        23
#
#     accuracy                           0.15       158
#    macro avg       0.07      0.50      0.13       158
# weighted avg       0.02      0.15      0.04       158
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-963472440.py in <cell line: 0>()
#     254
#     255         # ROC curve
# --> 256         fpr, tpr, _ = roc_curve(y_test, predicted_probs)
#     257         ax1.plot(fpr, tpr, 'b-', linewidth=2, label=f'AUC = {auc_val:.3f}')
#     258         ax1.plot([0, 1], [0, 1], 'k--', linewidth=1)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#    1148     array([ inf, 0.8 , 0.4 , 0.35, 0.1 ])
#    1149     """
# -> 1150     fps, tps, thresholds = _binary_clf_curve(
#    1151         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#    1152     )
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     833         sample_weight = sample_weight[nonzero_weight_mask]
#     834
# --> 835     pos_label = _check_pos_label_consistency(pos_label, y_true)
#     836
#     837     # make y_true a boolean vector
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in _check_pos_label_consistency(pos_label, y_true)
#    2639         ):
#    2640             classes_repr = ", ".join([repr(c) for c in classes.tolist()])
# -> 2641             raise ValueError(
#    2642                 f"y_true takes value in {{{classes_repr}}} and pos_label is not "
#    2643                 "specified: either make y_true take value in {0, 1} or "
#
# ValueError: y_true takes value in {-1, 0} and pos_label is not specified: either make y_true take value in {0, 1} or {-1, 1} or pass pos_label explicitly.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve
from sklearn.feature_selection import VarianceThreshold
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1_l2
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

print("Step 0: Setting up environment...")

# Manual 3D array creation function
def create_3d_array(matrix_list):
    if len(matrix_list) == 0:
        raise ValueError("No matrices provided")

    # Get dimensions from first matrix
    n_samples = len(matrix_list)
    n_timesteps = matrix_list[0].shape[0]
    n_features = matrix_list[0].shape[1]

    # Create empty 3D array
    array_3d = np.zeros((n_samples, n_timesteps, n_features))

    # Fill array
    for i in range(n_samples):
        array_3d[i, :, :] = matrix_list[i]

    return array_3d

print("Environment setup complete!")

# Load the data
print("Loading pcdata.csv...")
try:
    sequential_data = pd.read_csv('pcdata.csv')
    print(f"Data loaded successfully! Shape: {sequential_data.shape}")
except FileNotFoundError:
    print("ERROR: pcdata.csv file not found.")
    exit()

print("\nStep 1: Improved LSTM data preparation with better feature selection...")

def prepare_lstm_improved(data, sequence_length=3):
    # Select only the most relevant and clean features
    essential_features = [
        # Demographic
        'AGE', 'ECOGGRN',
        # Dosing
        'EXDOSENN',
        # Tumor response
        'TARGETQN', 'NONTARQN',
        # AE counts (most important)
        'total_ae_events', 'serious_ae_count', 'grade3_plus_count',
        'grade3_count', 'grade4_count', 'grade5_count',
        # Treatment impact
        'drug_withdrawn', 'concomitant_treatment_given',
        # Time
        'VISDAY'
    ]

    # Check which feature columns exist in the data
    available_features = [col for col in essential_features if col in data.columns]
    print(f"Selected {len(available_features)} essential features")
    print(f"Features: {available_features}")

    # Prepare data
    data_prep = data.copy()

    # Create outcome variable
    if 'CANCDEAD' in data_prep.columns:
        data_prep['outcome'] = data_prep['CANCDEAD'].astype(int)
        # Ensure binary outcome (0, 1)
        if data_prep['outcome'].min() < 0:
            data_prep['outcome'] = (data_prep['outcome'] > 0).astype(int)
        print(f"Outcome distribution: {data_prep['outcome'].value_counts().to_dict()}")
    else:
        print("WARNING: CANCDEAD column not found.")
        return None

    # Remove patients with insufficient visits
    visit_counts = data_prep.groupby('RPT').size()
    valid_patients = visit_counts[visit_counts >= sequence_length].index
    data_prep = data_prep[data_prep['RPT'].isin(valid_patients)]

    print(f"Patients with sufficient visits: {len(valid_patients)}")

    # Convert features to numeric and handle missing values robustly
    for col in available_features:
        data_prep[col] = pd.to_numeric(data_prep[col], errors='coerce')
        # Use median imputation
        median_val = data_prep[col].median()
        data_prep[col] = data_prep[col].fillna(median_val)
        print(f"  {col}: median={median_val:.3f}, missing={data_prep[col].isna().sum()}")

    # Remove constant features
    constant_features = []
    for col in available_features:
        if data_prep[col].nunique() <= 1:
            constant_features.append(col)

    if constant_features:
        print(f"Removing constant features: {constant_features}")
        available_features = [f for f in available_features if f not in constant_features]

    patients = data_prep['RPT'].unique()
    sequences = []
    labels = []

    print(f"Processing {len(patients)} patients...")

    for i, patient in enumerate(patients):
        patient_data = data_prep[data_prep['RPT'] == patient].sort_values('VISDAY')

        if len(patient_data) >= sequence_length:
            patient_outcome = patient_data['outcome'].iloc[0]
            feature_matrix = patient_data[available_features].values

            # Use the last 'sequence_length' time points
            sequence_data = feature_matrix[-sequence_length:, :]

            sequences.append(sequence_data)
            labels.append(patient_outcome)

        if (i + 1) % 50 == 0:
            print(f"Processed {i + 1} patients...")

    print(f"Created {len(sequences)} sequences")

    if len(sequences) == 0:
        raise ValueError("No sequences created")

    # Create 3D array
    sequences_array = create_3d_array(sequences)

    return {
        'sequences': sequences_array,
        'labels': np.array(labels),
        'feature_names': available_features
    }

# Prepare the data
try:
    lstm_data = prepare_lstm_improved(sequential_data, sequence_length=3)
    if lstm_data is None:
        raise ValueError("Data preparation failed")

    print("SUCCESS: LSTM data prepared!")
    print(f"Sequences dimension: {lstm_data['sequences'].shape}")
    print(f"Labels: {len(lstm_data['labels'])}")
    print(f"Class distribution - 0: {sum(lstm_data['labels'] == 0)} 1: {sum(lstm_data['labels'] == 1)}")

except Exception as e:
    print(f"ERROR in data preparation: {e}")
    exit()

print("\nStep 2: Robust normalization with NaN handling...")

def robust_normalize_3d(array_3d, feature_names):
    dims = array_3d.shape
    print(f"Normalizing array with dimensions: {dims}")

    n_samples, n_timesteps, n_features = dims
    X_reshaped = array_3d.reshape(n_samples * n_timesteps, n_features)

    # Check for NaN and infinite values
    print(f"NaN values before cleaning: {np.isnan(X_reshaped).sum()}")
    print(f"Inf values before cleaning: {np.isinf(X_reshaped).sum()}")

    # Replace any remaining NaN/Inf with 0
    X_reshaped = np.nan_to_num(X_reshaped, nan=0.0, posinf=0.0, neginf=0.0)

    # Use RobustScaler which is less sensitive to outliers
    scaler = RobustScaler()
    X_normalized = scaler.fit_transform(X_reshaped)

    # Check for any issues after scaling
    if np.isnan(X_normalized).any() or np.isinf(X_normalized).any():
        print("WARNING: NaN/Inf values after scaling. Using fallback normalization.")
        # Fallback: manual robust normalization
        X_normalized = np.zeros_like(X_reshaped)
        for i in range(n_features):
            feature_data = X_reshaped[:, i]
            median = np.median(feature_data)
            iqr = np.percentile(feature_data, 75) - np.percentile(feature_data, 25)
            if iqr > 0:
                X_normalized[:, i] = (feature_data - median) / iqr
            else:
                # Constant feature, just center
                X_normalized[:, i] = feature_data - median

    # Reshape back to 3D
    array_3d_normalized = X_normalized.reshape(n_samples, n_timesteps, n_features)

    print(f"Normalization completed! Data range: [{array_3d_normalized.min():.3f}, {array_3d_normalized.max():.3f}]")
    print(f"NaN values after normalization: {np.isnan(array_3d_normalized).sum()}")

    return array_3d_normalized, scaler

if 'lstm_data' in locals():
    X_sequences, scaler = robust_normalize_3d(lstm_data['sequences'].copy(),
                                            lstm_data.get('feature_names'))
    y = lstm_data['labels']

    print(f"Final label distribution: 0: {sum(y == 0)}, 1: {sum(y == 1)}")
else:
    print("Cannot normalize - lstm_data not created")
    exit()

print("\nStep 3: Creating train-test split...")

if 'X_sequences' in locals() and 'y' in locals():
    # Final check for NaN
    if np.isnan(X_sequences).any():
        print("WARNING: NaN values detected in sequences. Replacing with 0.")
        X_sequences = np.nan_to_num(X_sequences)

    # Create stratified split
    X_train, X_test, y_train, y_test = train_test_split(
        X_sequences, y,
        test_size=0.3,
        random_state=42,  # Changed seed for different split
        stratify=y
    )

    print("Training set:")
    print(f"  Sequences: {X_train.shape}")
    print(f"  Labels: {len(y_train)} (0: {sum(y_train == 0)} 1: {sum(y_train == 1)})")

    print("Test set:")
    print(f"  Sequences: {X_test.shape}")
    print(f"  Labels: {len(y_test)} (0: {sum(y_test == 0)} 1: {sum(y_test == 1)})")

else:
    print("Cannot create split - data not available")
    exit()

print("\nStep 4: Building robust LSTM model...")

def build_robust_lstm_model(sequence_length, n_features):
    # Simpler, more robust model
    model = Sequential([
        LSTM(32,
             input_shape=(sequence_length, n_features),
             return_sequences=False,
             kernel_initializer='glorot_uniform',
             recurrent_initializer='orthogonal'),
        Dropout(0.3),

        Dense(16, activation='relu', kernel_initializer='he_normal'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(8, activation='relu', kernel_initializer='he_normal'),
        Dropout(0.1),

        Dense(1, activation='sigmoid', kernel_initializer='glorot_uniform')
    ])

    # Use a conservative optimizer
    optimizer = Adam(
        learning_rate=0.001,
        beta_1=0.9,
        beta_2=0.999,
        epsilon=1e-7,
        clipnorm=1.0  # Gradient clipping
    )

    model.compile(
        loss='binary_crossentropy',
        optimizer=optimizer,
        metrics=['accuracy', 'AUC']
    )

    return model

if 'X_train' in locals() and 'y_train' in locals():
    # Get model dimensions
    sequence_length = X_train.shape[1]
    n_features = X_train.shape[2]

    print("Building model for:")
    print(f"  Sequence length: {sequence_length}")
    print(f"  Features: {n_features}")
    print(f"  Training samples: {X_train.shape[0]}")

    # Calculate class weights
    class_counts = np.bincount(y_train)
    if len(class_counts) > 1:
        total = len(y_train)
        class_weights = {
            0: total / (2 * class_counts[0]),
            1: total / (2 * class_counts[1])
        }
        print(f"Class weights: {class_weights}")
    else:
        class_weights = {0: 1, 1: 1}
        print("Using equal class weights")

    # Build model
    lstm_model = build_robust_lstm_model(sequence_length, n_features)

    print("Model architecture:")
    lstm_model.summary()

    print("\nStep 5: Training LSTM model with careful monitoring...")

    # Enhanced callbacks
    early_stopping = EarlyStopping(
        monitor='val_auc' if len(np.unique(y_train)) > 1 else 'val_loss',
        patience=20,
        restore_best_weights=True,
        mode='max' if len(np.unique(y_train)) > 1 else 'min',
        verbose=1,
        min_delta=0.001
    )

    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=10,
        min_lr=1e-7,
        verbose=1,
        min_delta=0.001
    )

    # Prepare validation data
    if len(np.unique(y_train)) > 1:
        # Use proper validation split
        val_split = 0.2
    else:
        val_split = 0.0

    print("Starting training...")

    try:
        history = lstm_model.fit(
            x=X_train,
            y=y_train,
            epochs=100,
            batch_size=16,
            validation_split=val_split,
            class_weight=class_weights,
            verbose=1,
            callbacks=[early_stopping, reduce_lr],
            shuffle=True
        )

        print("Training completed successfully!")

    except Exception as e:
        print(f"Training failed: {e}")
        print("Trying with simpler configuration...")

        # Fallback training
        history = lstm_model.fit(
            x=X_train,
            y=y_train,
            epochs=50,
            batch_size=32,
            validation_split=0.0,
            verbose=1,
            shuffle=True
        )

else:
    print("Cannot build model - training data not available")
    exit()

print("\nStep 6: Evaluating LSTM model...")

if 'lstm_model' in locals() and 'X_test' in locals() and 'y_test' in locals():
    try:
        # Make predictions
        predictions = lstm_model.predict(X_test, verbose=0)
        predicted_probs = predictions.flatten()

        # Check for NaN in predictions
        if np.isnan(predicted_probs).any():
            print("WARNING: NaN in predictions. Using fallback.")
            predicted_probs = np.zeros_like(predicted_probs) + 0.5

        # Convert to binary predictions
        threshold = 0.5
        predicted_classes = (predicted_probs > threshold).astype(int)

        # Calculate metrics
        conf_matrix = confusion_matrix(y_test, predicted_classes)
        accuracy = np.sum(np.diag(conf_matrix)) / np.sum(conf_matrix)

        if conf_matrix.shape == (2, 2):
            tn, fp, fn, tp = conf_matrix.ravel()
            sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
            specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
            precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        else:
            sensitivity = specificity = precision = accuracy

        # AUC
        if len(np.unique(y_test)) > 1:
            try:
                auc_val = roc_auc_score(y_test, predicted_probs)
            except:
                auc_val = 0.5
        else:
            auc_val = 0.5

        # Print results
        print("=" * 60)
        print("ROBUST LSTM MODEL PERFORMANCE")
        print("=" * 60)
        print(f"Accuracy:    {accuracy:.3f}")
        print(f"Sensitivity: {sensitivity:.3f}")
        print(f"Specificity: {specificity:.3f}")
        print(f"Precision:   {precision:.3f}")
        print(f"AUC:         {auc_val:.3f}")
        print(f"\nConfusion Matrix:")
        print(conf_matrix)

        if len(np.unique(y_test)) > 1:
            print(f"\nClassification Report:")
            print(classification_report(y_test, predicted_classes,
                                      target_names=['Class 0', 'Class 1']))

        # Plot results
        fig, axes = plt.subplots(1, 2, figsize=(12, 5))

        # ROC curve
        if len(np.unique(y_test)) > 1:
            fpr, tpr, _ = roc_curve(y_test, predicted_probs)
            axes[0].plot(fpr, tpr, 'b-', linewidth=2, label=f'AUC = {auc_val:.3f}')
            axes[0].plot([0, 1], [0, 1], 'k--', linewidth=1)
            axes[0].set_xlabel('False Positive Rate')
            axes[0].set_ylabel('True Positive Rate')
            axes[0].set_title('ROC Curve')
            axes[0].legend()
            axes[0].grid(True)
        else:
            axes[0].text(0.5, 0.5, 'Single class\nNo ROC curve',
                        ha='center', va='center', transform=axes[0].transAxes)
            axes[0].set_title('ROC Curve')

        # Training history (if available)
        if 'history' in locals() and 'loss' in history.history:
            axes[1].plot(history.history['loss'], 'b-', label='Train Loss')
            if 'val_loss' in history.history and len(history.history['val_loss']) > 0:
                axes[1].plot(history.history['val_loss'], 'r-', label='Val Loss')
            axes[1].set_xlabel('Epoch')
            axes[1].set_ylabel('Loss')
            axes[1].set_title('Training History')
            axes[1].legend()
            axes[1].grid(True)
        else:
            axes[1].text(0.5, 0.5, 'No training history\navailable',
                        ha='center', va='center', transform=axes[1].transAxes)
            axes[1].set_title('Training History')

        plt.tight_layout()
        plt.show()

    except Exception as e:
        print(f"Error in evaluation: {e}")
        print("This indicates the model didn't train properly.")

else:
    print("Cannot evaluate - model or test data not available")

print("\nStep 7: Data quality summary...")
if 'lstm_data' in locals():
    print("Data Quality Report:")
    print(f"Total sequences: {len(lstm_data['labels'])}")
    print(f"Feature count: {lstm_data['sequences'].shape[2]}")
    print(f"Class balance: {np.bincount(lstm_data['labels'])}")
    print(f"Sequence length: {lstm_data['sequences'].shape[1]}")

    # Check data statistics
    X_flat = lstm_data['sequences'].reshape(-1, lstm_data['sequences'].shape[2])
    print(f"Data statistics:")
    print(f"  Min: {X_flat.min():.3f}")
    print(f"  Max: {X_flat.max():.3f}")
    print(f"  Mean: {X_flat.mean():.3f}")
    print(f"  Std: {X_flat.std():.3f}")
    print(f"  NaN values: {np.isnan(X_flat).sum()}")
    print(f"  Inf values: {np.isinf(X_flat).sum()}")
# Out:
# Step 0: Setting up environment...
# Environment setup complete!
# Loading pcdata.csv...
# Data loaded successfully! Shape: (8121, 101)
#
# Step 1: Improved LSTM data preparation with better feature selection...
# Selected 14 essential features
# Features: ['AGE', 'ECOGGRN', 'EXDOSENN', 'TARGETQN', 'NONTARQN', 'total_ae_events', 'serious_ae_count', 'grade3_plus_count', 'grade3_count', 'grade4_count', 'grade5_count', 'drug_withdrawn', 'concomitant_treatment_given', 'VISDAY']
# Outcome distribution: {0: 7051, 1: 1070}
# Patients with sufficient visits: 525
#   AGE: median=68.000, missing=0
#   ECOGGRN: median=1.000, missing=0
#   EXDOSENN: median=1.000, missing=0
#   TARGETQN: median=1.000, missing=0
#   NONTARQN: median=1.000, missing=0
#   total_ae_events: median=7.000, missing=0
#   serious_ae_count: median=0.000, missing=0
#   grade3_plus_count: median=0.000, missing=0
#   grade3_count: median=0.000, missing=0
#   grade4_count: median=0.000, missing=0
#   grade5_count: median=0.000, missing=0
#   drug_withdrawn: median=0.000, missing=0
#   concomitant_treatment_given: median=1.000, missing=0
#   VISDAY: median=106.000, missing=0
# Processing 525 patients...
# Processed 50 patients...
# Processed 100 patients...
# Processed 150 patients...
# Processed 200 patients...
# Processed 250 patients...
# Processed 300 patients...
# Processed 350 patients...
# Processed 400 patients...
# Processed 450 patients...
# Processed 500 patients...
# Created 525 sequences
# SUCCESS: LSTM data prepared!
# Sequences dimension: (525, 3, 14)
# Labels: 525
# Class distribution - 0: 449 1: 76
#
# Step 2: Robust normalization with NaN handling...
# Normalizing array with dimensions: (525, 3, 14)
# NaN values before cleaning: 0
# Inf values before cleaning: 0
# Normalization completed! Data range: [-2.000, 9.000]
# NaN values after normalization: 0
# Final label distribution: 0: 449, 1: 76
#
# Step 3: Creating train-test split...
# Training set:
#   Sequences: (367, 3, 14)
#   Labels: 367 (0: 314 1: 53)
# Test set:
#   Sequences: (158, 3, 14)
#   Labels: 158 (0: 135 1: 23)
#
# Step 4: Building robust LSTM model...
# Building model for:
#   Sequence length: 3
#   Features: 14
#   Training samples: 367
# Class weights: {0: np.float64(0.5843949044585988), 1: np.float64(3.4622641509433962)}
# Model architecture:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 32)             │         6,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,753 (26.38 KB)
#  Trainable params: 6,721 (26.25 KB)
#  Non-trainable params: 32 (128.00 B)
# Step 5: Training LSTM model with careful monitoring...
# Starting training...
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - AUC: 0.4302 - accuracy: 0.6554 - loss: 0.8703 - val_AUC: 0.7860 - val_accuracy: 0.6351 - val_loss: 0.6860 - learning_rate: 0.0010
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.5971 - accuracy: 0.6619 - loss: 0.7475 - val_AUC: 0.7576 - val_accuracy: 0.3649 - val_loss: 0.6966 - learning_rate: 0.0010
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.6488 - accuracy: 0.7137 - loss: 0.5893 - val_AUC: 0.6903 - val_accuracy: 0.3784 - val_loss: 0.6978 - learning_rate: 0.0010
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.5825 - accuracy: 0.6508 - loss: 0.8086 - val_AUC: 0.6591 - val_accuracy: 0.3378 - val_loss: 0.6996 - learning_rate: 0.0010
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7651 - accuracy: 0.6663 - loss: 0.6172 - val_AUC: 0.6297 - val_accuracy: 0.3243 - val_loss: 0.6995 - learning_rate: 0.0010
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7152 - accuracy: 0.6294 - loss: 0.6319 - val_AUC: 0.6155 - val_accuracy: 0.3243 - val_loss: 0.7006 - learning_rate: 0.0010
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7636 - accuracy: 0.6579 - loss: 0.5675 - val_AUC: 0.5758 - val_accuracy: 0.3514 - val_loss: 0.6942 - learning_rate: 0.0010
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.7663 - accuracy: 0.6501 - loss: 0.5580 - val_AUC: 0.5767 - val_accuracy: 0.3514 - val_loss: 0.6891 - learning_rate: 0.0010
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7825 - accuracy: 0.6310 - loss: 0.5559 - val_AUC: 0.5900 - val_accuracy: 0.3514 - val_loss: 0.6835 - learning_rate: 0.0010
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7298 - accuracy: 0.6149 - loss: 0.5883 - val_AUC: 0.6108 - val_accuracy: 0.3784 - val_loss: 0.6737 - learning_rate: 0.0010
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7648 - accuracy: 0.6386 - loss: 0.5674 - val_AUC: 0.6146 - val_accuracy: 0.3919 - val_loss: 0.6733 - learning_rate: 0.0010
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7323 - accuracy: 0.6213 - loss: 0.5904 - val_AUC: 0.6184 - val_accuracy: 0.4054 - val_loss: 0.6774 - learning_rate: 0.0010
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7917 - accuracy: 0.6265 - loss: 0.5407 - val_AUC: 0.6212 - val_accuracy: 0.4324 - val_loss: 0.6722 - learning_rate: 0.0010
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8053 - accuracy: 0.6823 - loss: 0.5458 - val_AUC: 0.6146 - val_accuracy: 0.4459 - val_loss: 0.6688 - learning_rate: 0.0010
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7618 - accuracy: 0.6502 - loss: 0.6050 - val_AUC: 0.5890 - val_accuracy: 0.4730 - val_loss: 0.6671 - learning_rate: 0.0010
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8056 - accuracy: 0.6409 - loss: 0.5698 - val_AUC: 0.5938 - val_accuracy: 0.4459 - val_loss: 0.6651 - learning_rate: 0.0010
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.7946 - accuracy: 0.6499 - loss: 0.5376 - val_AUC: 0.5938 - val_accuracy: 0.4595 - val_loss: 0.6611 - learning_rate: 0.0010
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8068 - accuracy: 0.6298 - loss: 0.5319 - val_AUC: 0.5938 - val_accuracy: 0.4595 - val_loss: 0.6613 - learning_rate: 0.0010
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8386 - accuracy: 0.6997 - loss: 0.5554 - val_AUC: 0.5900 - val_accuracy: 0.4730 - val_loss: 0.6711 - learning_rate: 0.0010
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7688 - accuracy: 0.5908 - loss: 0.5592 - val_AUC: 0.5994 - val_accuracy: 0.5000 - val_loss: 0.6677 - learning_rate: 0.0010
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7681 - accuracy: 0.6517 - loss: 0.5175 - val_AUC: 0.5938 - val_accuracy: 0.4730 - val_loss: 0.6512 - learning_rate: 0.0010
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8389 - accuracy: 0.7045 - loss: 0.4780 - val_AUC: 0.6023 - val_accuracy: 0.5000 - val_loss: 0.6674 - learning_rate: 0.0010
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8540 - accuracy: 0.6986 - loss: 0.4951 - val_AUC: 0.6165 - val_accuracy: 0.5270 - val_loss: 0.6833 - learning_rate: 0.0010
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8638 - accuracy: 0.7143 - loss: 0.4680 - val_AUC: 0.6155 - val_accuracy: 0.5135 - val_loss: 0.6605 - learning_rate: 0.0010
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8473 - accuracy: 0.6778 - loss: 0.5207 - val_AUC: 0.6165 - val_accuracy: 0.5541 - val_loss: 0.6342 - learning_rate: 0.0010
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8253 - accuracy: 0.7119 - loss: 0.4566 - val_AUC: 0.6222 - val_accuracy: 0.5541 - val_loss: 0.6300 - learning_rate: 0.0010
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.7972 - accuracy: 0.6846 - loss: 0.5624 - val_AUC: 0.6288 - val_accuracy: 0.5676 - val_loss: 0.6426 - learning_rate: 0.0010
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8271 - accuracy: 0.6947 - loss: 0.4891 - val_AUC: 0.6136 - val_accuracy: 0.5541 - val_loss: 0.6490 - learning_rate: 0.0010
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8648 - accuracy: 0.6951 - loss: 0.4628 - val_AUC: 0.6241 - val_accuracy: 0.5405 - val_loss: 0.6603 - learning_rate: 0.0010
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8236 - accuracy: 0.6773 - loss: 0.4776 - val_AUC: 0.6127 - val_accuracy: 0.5405 - val_loss: 0.6535 - learning_rate: 0.0010
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8383 - accuracy: 0.7000 - loss: 0.5064 - val_AUC: 0.6278 - val_accuracy: 0.5541 - val_loss: 0.6655 - learning_rate: 0.0010
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8412 - accuracy: 0.6997 - loss: 0.5160 - val_AUC: 0.6250 - val_accuracy: 0.5270 - val_loss: 0.6804 - learning_rate: 0.0010
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.8770 - accuracy: 0.7351 - loss: 0.4509 - val_AUC: 0.6051 - val_accuracy: 0.5405 - val_loss: 0.6797 - learning_rate: 0.0010
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.8411 - accuracy: 0.6617 - loss: 0.4516 - val_AUC: 0.6136 - val_accuracy: 0.5405 - val_loss: 0.6924 - learning_rate: 0.0010
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.8599 - accuracy: 0.6915 - loss: 0.5134 - val_AUC: 0.6250 - val_accuracy: 0.5405 - val_loss: 0.6981 - learning_rate: 0.0010
# Epoch 36/100
# 16/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.9154 - accuracy: 0.7142 - loss: 0.3990
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9099 - accuracy: 0.7110 - loss: 0.4029 - val_AUC: 0.6288 - val_accuracy: 0.5270 - val_loss: 0.6939 - learning_rate: 0.0010
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.8221 - accuracy: 0.6723 - loss: 0.4791 - val_AUC: 0.6383 - val_accuracy: 0.5270 - val_loss: 0.7076 - learning_rate: 5.0000e-04
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - AUC: 0.9060 - accuracy: 0.6926 - loss: 0.4048 - val_AUC: 0.6316 - val_accuracy: 0.5270 - val_loss: 0.7151 - learning_rate: 5.0000e-04
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.8786 - accuracy: 0.7095 - loss: 0.4347 - val_AUC: 0.6373 - val_accuracy: 0.5135 - val_loss: 0.7258 - learning_rate: 5.0000e-04
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8688 - accuracy: 0.6788 - loss: 0.4335 - val_AUC: 0.6420 - val_accuracy: 0.5135 - val_loss: 0.7168 - learning_rate: 5.0000e-04
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8798 - accuracy: 0.6973 - loss: 0.4024 - val_AUC: 0.6402 - val_accuracy: 0.5270 - val_loss: 0.7117 - learning_rate: 5.0000e-04
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8510 - accuracy: 0.6950 - loss: 0.5081 - val_AUC: 0.6326 - val_accuracy: 0.5135 - val_loss: 0.7287 - learning_rate: 5.0000e-04
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8837 - accuracy: 0.7164 - loss: 0.4173 - val_AUC: 0.6373 - val_accuracy: 0.5000 - val_loss: 0.7370 - learning_rate: 5.0000e-04
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8835 - accuracy: 0.7331 - loss: 0.4293 - val_AUC: 0.6354 - val_accuracy: 0.5000 - val_loss: 0.7454 - learning_rate: 5.0000e-04
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8661 - accuracy: 0.7446 - loss: 0.4914 - val_AUC: 0.6383 - val_accuracy: 0.5135 - val_loss: 0.7275 - learning_rate: 5.0000e-04
# Epoch 46/100
# 12/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.7652 - accuracy: 0.6625 - loss: 0.7210
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8015 - accuracy: 0.6851 - loss: 0.6248 - val_AUC: 0.6364 - val_accuracy: 0.5270 - val_loss: 0.7076 - learning_rate: 5.0000e-04
# Epoch 47/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8847 - accuracy: 0.7164 - loss: 0.4020 - val_AUC: 0.6345 - val_accuracy: 0.5135 - val_loss: 0.7099 - learning_rate: 2.5000e-04
# Epoch 48/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8680 - accuracy: 0.7360 - loss: 0.4290 - val_AUC: 0.6383 - val_accuracy: 0.5135 - val_loss: 0.7098 - learning_rate: 2.5000e-04
# Epoch 49/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8803 - accuracy: 0.6976 - loss: 0.4221 - val_AUC: 0.6383 - val_accuracy: 0.5135 - val_loss: 0.7104 - learning_rate: 2.5000e-04
# Epoch 50/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8598 - accuracy: 0.7129 - loss: 0.4290 - val_AUC: 0.6392 - val_accuracy: 0.5270 - val_loss: 0.7183 - learning_rate: 2.5000e-04
# Epoch 51/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8792 - accuracy: 0.6884 - loss: 0.3951 - val_AUC: 0.6373 - val_accuracy: 0.5270 - val_loss: 0.7405 - learning_rate: 2.5000e-04
# Epoch 52/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8800 - accuracy: 0.7339 - loss: 0.4154 - val_AUC: 0.6383 - val_accuracy: 0.5270 - val_loss: 0.7399 - learning_rate: 2.5000e-04
# Epoch 53/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8595 - accuracy: 0.6945 - loss: 0.4411 - val_AUC: 0.6335 - val_accuracy: 0.5270 - val_loss: 0.7513 - learning_rate: 2.5000e-04
# Epoch 54/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8632 - accuracy: 0.7022 - loss: 0.4505 - val_AUC: 0.6345 - val_accuracy: 0.5270 - val_loss: 0.7545 - learning_rate: 2.5000e-04
# Epoch 55/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8763 - accuracy: 0.7266 - loss: 0.4267 - val_AUC: 0.6345 - val_accuracy: 0.5270 - val_loss: 0.7568 - learning_rate: 2.5000e-04
# Epoch 56/100
# 12/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9091 - accuracy: 0.7258 - loss: 0.4033
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8980 - accuracy: 0.7150 - loss: 0.4155 - val_AUC: 0.6373 - val_accuracy: 0.5135 - val_loss: 0.7531 - learning_rate: 2.5000e-04
# Epoch 57/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8442 - accuracy: 0.6622 - loss: 0.4783 - val_AUC: 0.6411 - val_accuracy: 0.5135 - val_loss: 0.7565 - learning_rate: 1.2500e-04
# Epoch 58/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8881 - accuracy: 0.7449 - loss: 0.4229 - val_AUC: 0.6430 - val_accuracy: 0.5135 - val_loss: 0.7488 - learning_rate: 1.2500e-04
# Epoch 59/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8693 - accuracy: 0.6929 - loss: 0.4083 - val_AUC: 0.6392 - val_accuracy: 0.5135 - val_loss: 0.7520 - learning_rate: 1.2500e-04
# Epoch 60/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8831 - accuracy: 0.7235 - loss: 0.4233 - val_AUC: 0.6373 - val_accuracy: 0.5135 - val_loss: 0.7502 - learning_rate: 1.2500e-04
# Epoch 61/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8958 - accuracy: 0.7126 - loss: 0.3880 - val_AUC: 0.6373 - val_accuracy: 0.5135 - val_loss: 0.7505 - learning_rate: 1.2500e-04
# Epoch 62/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8784 - accuracy: 0.7311 - loss: 0.4618 - val_AUC: 0.6402 - val_accuracy: 0.5135 - val_loss: 0.7560 - learning_rate: 1.2500e-04
# Epoch 63/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8958 - accuracy: 0.7363 - loss: 0.3789 - val_AUC: 0.6383 - val_accuracy: 0.5135 - val_loss: 0.7432 - learning_rate: 1.2500e-04
# Epoch 64/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8923 - accuracy: 0.7297 - loss: 0.4229 - val_AUC: 0.6420 - val_accuracy: 0.5270 - val_loss: 0.7426 - learning_rate: 1.2500e-04
# Epoch 65/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8962 - accuracy: 0.7044 - loss: 0.4075 - val_AUC: 0.6402 - val_accuracy: 0.5135 - val_loss: 0.7385 - learning_rate: 1.2500e-04
# Epoch 66/100
# 12/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8465 - accuracy: 0.6760 - loss: 0.5020
# Epoch 66: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8430 - accuracy: 0.6832 - loss: 0.5079 - val_AUC: 0.6345 - val_accuracy: 0.5135 - val_loss: 0.7437 - learning_rate: 1.2500e-04
# Epoch 67/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8899 - accuracy: 0.7190 - loss: 0.4136 - val_AUC: 0.6335 - val_accuracy: 0.5270 - val_loss: 0.7449 - learning_rate: 6.2500e-05
# Epoch 68/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8677 - accuracy: 0.7103 - loss: 0.4197 - val_AUC: 0.6335 - val_accuracy: 0.5270 - val_loss: 0.7466 - learning_rate: 6.2500e-05
# Epoch 69/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9129 - accuracy: 0.7206 - loss: 0.3918 - val_AUC: 0.6326 - val_accuracy: 0.5135 - val_loss: 0.7482 - learning_rate: 6.2500e-05
# Epoch 70/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8698 - accuracy: 0.7294 - loss: 0.4335 - val_AUC: 0.6335 - val_accuracy: 0.5270 - val_loss: 0.7450 - learning_rate: 6.2500e-05
# Epoch 71/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8987 - accuracy: 0.7002 - loss: 0.4017 - val_AUC: 0.6326 - val_accuracy: 0.5270 - val_loss: 0.7449 - learning_rate: 6.2500e-05
# Epoch 72/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8546 - accuracy: 0.7011 - loss: 0.4412 - val_AUC: 0.6345 - val_accuracy: 0.5270 - val_loss: 0.7459 - learning_rate: 6.2500e-05
# Epoch 73/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8788 - accuracy: 0.7142 - loss: 0.4494 - val_AUC: 0.6345 - val_accuracy: 0.5270 - val_loss: 0.7418 - learning_rate: 6.2500e-05
# Epoch 74/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8942 - accuracy: 0.6975 - loss: 0.4161 - val_AUC: 0.6364 - val_accuracy: 0.5270 - val_loss: 0.7426 - learning_rate: 6.2500e-05
# Epoch 75/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8716 - accuracy: 0.6770 - loss: 0.4226 - val_AUC: 0.6345 - val_accuracy: 0.5270 - val_loss: 0.7421 - learning_rate: 6.2500e-05
# Epoch 76/100
# 12/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8128 - accuracy: 0.6900 - loss: 0.5347
# Epoch 76: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8292 - accuracy: 0.6972 - loss: 0.5035 - val_AUC: 0.6354 - val_accuracy: 0.5270 - val_loss: 0.7483 - learning_rate: 6.2500e-05
# Epoch 77/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8629 - accuracy: 0.7188 - loss: 0.4681 - val_AUC: 0.6373 - val_accuracy: 0.5135 - val_loss: 0.7572 - learning_rate: 3.1250e-05
# Epoch 78/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8848 - accuracy: 0.7229 - loss: 0.4225 - val_AUC: 0.6373 - val_accuracy: 0.5135 - val_loss: 0.7588 - learning_rate: 3.1250e-05
# Epoch 79/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8641 - accuracy: 0.6959 - loss: 0.4514 - val_AUC: 0.6345 - val_accuracy: 0.5135 - val_loss: 0.7469 - learning_rate: 3.1250e-05
# Epoch 80/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8776 - accuracy: 0.6817 - loss: 0.4298 - val_AUC: 0.6354 - val_accuracy: 0.5135 - val_loss: 0.7500 - learning_rate: 3.1250e-05
# Epoch 81/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9049 - accuracy: 0.7610 - loss: 0.3934 - val_AUC: 0.6373 - val_accuracy: 0.5135 - val_loss: 0.7544 - learning_rate: 3.1250e-05
# Epoch 82/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8691 - accuracy: 0.7086 - loss: 0.4305 - val_AUC: 0.6373 - val_accuracy: 0.5270 - val_loss: 0.7593 - learning_rate: 3.1250e-05
# Epoch 83/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8200 - accuracy: 0.6896 - loss: 0.5229 - val_AUC: 0.6383 - val_accuracy: 0.5270 - val_loss: 0.7588 - learning_rate: 3.1250e-05
# Epoch 84/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8980 - accuracy: 0.7417 - loss: 0.4043 - val_AUC: 0.6364 - val_accuracy: 0.5270 - val_loss: 0.7567 - learning_rate: 3.1250e-05
# Epoch 85/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8901 - accuracy: 0.7458 - loss: 0.4649 - val_AUC: 0.6354 - val_accuracy: 0.5270 - val_loss: 0.7542 - learning_rate: 3.1250e-05
# Epoch 86/100
# 15/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8710 - accuracy: 0.6798 - loss: 0.4029
# Epoch 86: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.8738 - accuracy: 0.6882 - loss: 0.4055 - val_AUC: 0.6354 - val_accuracy: 0.5270 - val_loss: 0.7524 - learning_rate: 3.1250e-05
# Epoch 87/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.8880 - accuracy: 0.6862 - loss: 0.4802 - val_AUC: 0.6373 - val_accuracy: 0.5135 - val_loss: 0.7565 - learning_rate: 1.5625e-05
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.8887 - accuracy: 0.7174 - loss: 0.4480 - val_AUC: 0.6383 - val_accuracy: 0.5270 - val_loss: 0.7602 - learning_rate: 1.5625e-05
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.8835 - accuracy: 0.7193 - loss: 0.4071 - val_AUC: 0.6373 - val_accuracy: 0.5135 - val_loss: 0.7614 - learning_rate: 1.5625e-05
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.8572 - accuracy: 0.7081 - loss: 0.4588 - val_AUC: 0.6354 - val_accuracy: 0.5270 - val_loss: 0.7608 - learning_rate: 1.5625e-05
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.9081 - accuracy: 0.7530 - loss: 0.4464 - val_AUC: 0.6392 - val_accuracy: 0.5270 - val_loss: 0.7569 - learning_rate: 1.5625e-05
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8765 - accuracy: 0.7202 - loss: 0.4709 - val_AUC: 0.6383 - val_accuracy: 0.5270 - val_loss: 0.7559 - learning_rate: 1.5625e-05
# Epoch 93/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8548 - accuracy: 0.6991 - loss: 0.4513 - val_AUC: 0.6373 - val_accuracy: 0.5270 - val_loss: 0.7526 - learning_rate: 1.5625e-05
# Epoch 94/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9036 - accuracy: 0.7069 - loss: 0.3870 - val_AUC: 0.6364 - val_accuracy: 0.5270 - val_loss: 0.7439 - learning_rate: 1.5625e-05
# Epoch 95/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8721 - accuracy: 0.7258 - loss: 0.4173 - val_AUC: 0.6364 - val_accuracy: 0.5270 - val_loss: 0.7445 - learning_rate: 1.5625e-05
# Epoch 96/100
# 11/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8977 - accuracy: 0.6843 - loss: 0.4289
# Epoch 96: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8857 - accuracy: 0.6896 - loss: 0.4287 - val_AUC: 0.6383 - val_accuracy: 0.5270 - val_loss: 0.7437 - learning_rate: 1.5625e-05
# Epoch 97/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8943 - accuracy: 0.7507 - loss: 0.3658 - val_AUC: 0.6364 - val_accuracy: 0.5270 - val_loss: 0.7405 - learning_rate: 7.8125e-06
# Epoch 98/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8778 - accuracy: 0.7225 - loss: 0.4158 - val_AUC: 0.6373 - val_accuracy: 0.5270 - val_loss: 0.7430 - learning_rate: 7.8125e-06
# Epoch 99/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9050 - accuracy: 0.7228 - loss: 0.3867 - val_AUC: 0.6373 - val_accuracy: 0.5270 - val_loss: 0.7451 - learning_rate: 7.8125e-06
# Epoch 100/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8858 - accuracy: 0.7082 - loss: 0.3907 - val_AUC: 0.6383 - val_accuracy: 0.5270 - val_loss: 0.7476 - learning_rate: 7.8125e-06
# Training completed successfully!
#
# Step 6: Evaluating LSTM model...
# ============================================================
# ROBUST LSTM MODEL PERFORMANCE
# ============================================================
# Accuracy:    0.608
# Sensitivity: 0.609
# Specificity: 0.607
# Precision:   0.209
# AUC:         0.719
#
# Confusion Matrix:
# [[82 53]
#  [ 9 14]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.90      0.61      0.73       135
#      Class 1       0.21      0.61      0.31        23
#
#     accuracy                           0.61       158
#    macro avg       0.56      0.61      0.52       158
# weighted avg       0.80      0.61      0.67       158
# Step 7: Data quality summary...
# Data Quality Report:
# Total sequences: 525
# Feature count: 14
# Class balance: [449  76]
# Sequence length: 3
# Data statistics:
#   Min: 0.000
#   Max: 750.000
#   Mean: 24.249
#   Std: 74.058
#   NaN values: 0
#   Inf values: 0

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve, precision_recall_curve
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Conv1D, MaxPooling1D, GlobalMaxPooling1D
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.metrics import Precision, Recall
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

print("Step 0: Setting up environment...")

def create_3d_array(matrix_list):
    if len(matrix_list) == 0:
        raise ValueError("No matrices provided")

    n_samples = len(matrix_list)
    n_timesteps = matrix_list[0].shape[0]
    n_features = matrix_list[0].shape[1]

    array_3d = np.zeros((n_samples, n_timesteps, n_features))

    for i in range(n_samples):
        array_3d[i, :, :] = matrix_list[i]

    return array_3d

print("Environment setup complete!")

# Load the data
print("Loading pcdata.csv...")
try:
    sequential_data = pd.read_csv('pcdata.csv')
    print(f"Data loaded successfully! Shape: {sequential_data.shape}")
except FileNotFoundError:
    print("ERROR: pcdata.csv file not found.")
    exit()

print("\nStep 1: Enhanced LSTM data preparation...")

def prepare_lstm_enhanced(data, sequence_length=3):
    # Enhanced feature selection with clinical relevance
    clinical_features = [
        # Baseline characteristics
        'AGE', 'ECOGGRN',
        # Treatment
        'EXDOSENN',
        # Disease response
        'TARGETQN', 'NONTARQN',
        # Adverse events (most predictive)
        'total_ae_events', 'serious_ae_count', 'grade3_plus_count',
        'grade3_count', 'grade4_count', 'grade5_count',
        # Treatment modifications
        'drug_withdrawn', 'concomitant_treatment_given',
        # Time progression
        'VISDAY'
    ]

    # Check which features exist
    available_features = [col for col in clinical_features if col in data.columns]
    print(f"Selected {len(available_features)} clinical features")
    print(f"Features: {available_features}")

    # Prepare data
    data_prep = data.copy()

    # Create outcome variable
    if 'CANCDEAD' in data_prep.columns:
        data_prep['outcome'] = data_prep['CANCDEAD'].astype(int)
        if data_prep['outcome'].min() < 0:
            data_prep['outcome'] = (data_prep['outcome'] > 0).astype(int)
        print(f"Outcome distribution: {data_prep['outcome'].value_counts().to_dict()}")
    else:
        print("WARNING: CANCDEAD column not found.")
        return None

    # Filter patients with sufficient visits
    visit_counts = data_prep.groupby('RPT').size()
    valid_patients = visit_counts[visit_counts >= sequence_length].index
    data_prep = data_prep[data_prep['RPT'].isin(valid_patients)]

    print(f"Patients with sufficient visits: {len(valid_patients)}")

    # Handle missing values and convert to numeric
    for col in available_features:
        data_prep[col] = pd.to_numeric(data_prep[col], errors='coerce')
        median_val = data_prep[col].median()
        data_prep[col] = data_prep[col].fillna(median_val)
        print(f"  {col}: median={median_val:.3f}")

    # Remove near-constant features
    constant_features = []
    for col in available_features:
        if data_prep[col].nunique() <= 1:
            constant_features.append(col)

    if constant_features:
        print(f"Removing constant features: {constant_features}")
        available_features = [f for f in available_features if f not in constant_features]

    patients = data_prep['RPT'].unique()
    sequences = []
    labels = []

    print(f"Processing {len(patients)} patients...")

    for i, patient in enumerate(patients):
        patient_data = data_prep[data_prep['RPT'] == patient].sort_values('VISDAY')

        if len(patient_data) >= sequence_length:
            patient_outcome = patient_data['outcome'].iloc[0]
            feature_matrix = patient_data[available_features].values

            # Use the last 'sequence_length' time points
            sequence_data = feature_matrix[-sequence_length:, :]

            sequences.append(sequence_data)
            labels.append(patient_outcome)

        if (i + 1) % 50 == 0:
            print(f"Processed {i + 1} patients...")

    print(f"Created {len(sequences)} sequences")

    if len(sequences) == 0:
        raise ValueError("No sequences created")

    # Create 3D array
    sequences_array = create_3d_array(sequences)

    return {
        'sequences': sequences_array,
        'labels': np.array(labels),
        'feature_names': available_features
    }

# Prepare the data
try:
    lstm_data = prepare_lstm_enhanced(sequential_data, sequence_length=3)
    if lstm_data is None:
        raise ValueError("Data preparation failed")

    print("SUCCESS: LSTM data prepared!")
    print(f"Sequences dimension: {lstm_data['sequences'].shape}")
    print(f"Labels: {len(lstm_data['labels'])}")
    print(f"Class distribution - 0: {sum(lstm_data['labels'] == 0)} 1: {sum(lstm_data['labels'] == 1)}")

except Exception as e:
    print(f"ERROR in data preparation: {e}")
    exit()

print("\nStep 2: Advanced normalization...")

def advanced_normalize_3d(array_3d, feature_names):
    dims = array_3d.shape
    print(f"Normalizing array with dimensions: {dims}")

    n_samples, n_timesteps, n_features = dims
    X_reshaped = array_3d.reshape(n_samples * n_timesteps, n_features)

    # Clean any remaining issues
    X_reshaped = np.nan_to_num(X_reshaped, nan=0.0, posinf=0.0, neginf=0.0)

    # Use different scalers for different feature types
    X_normalized = np.zeros_like(X_reshaped)

    for i, feature_name in enumerate(feature_names):
        feature_data = X_reshaped[:, i]

        # Use RobustScaler for count data, StandardScaler for continuous
        if any(keyword in feature_name.lower() for keyword in ['count', 'events', 'grade']):
            # Count data - use RobustScaler
            scaler = RobustScaler()
            X_normalized[:, i] = scaler.fit_transform(feature_data.reshape(-1, 1)).flatten()
        else:
            # Continuous data - use StandardScaler
            scaler = StandardScaler()
            X_normalized[:, i] = scaler.fit_transform(feature_data.reshape(-1, 1)).flatten()

    # Reshape back to 3D
    array_3d_normalized = X_normalized.reshape(n_samples, n_timesteps, n_features)

    print(f"Advanced normalization completed! Data range: [{array_3d_normalized.min():.3f}, {array_3d_normalized.max():.3f}]")

    return array_3d_normalized

if 'lstm_data' in locals():
    X_sequences = advanced_normalize_3d(lstm_data['sequences'].copy(),
                                      lstm_data.get('feature_names'))
    y = lstm_data['labels']

    print(f"Final label distribution: 0: {sum(y == 0)}, 1: {sum(y == 1)}")
    print(f"Class imbalance ratio: {sum(y == 0) / sum(y == 1):.2f}:1")
else:
    print("Cannot normalize - lstm_data not created")
    exit()

print("\nStep 3: Strategic train-test split...")

if 'X_sequences' in locals() and 'y' in locals():
    # Use stratification with random state for reproducibility
    X_train, X_test, y_train, y_test = train_test_split(
        X_sequences, y,
        test_size=0.25,  # Slightly more training data
        random_state=42,
        stratify=y
    )

    # Further split training for validation
    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train,
        test_size=0.2,
        random_state=42,
        stratify=y_train
    )

    print("Data splits:")
    print(f"Training:   {X_train.shape} (0: {sum(y_train == 0)} 1: {sum(y_train == 1)})")
    print(f"Validation: {X_val.shape} (0: {sum(y_val == 0)} 1: {sum(y_val == 1)})")
    print(f"Test:       {X_test.shape} (0: {sum(y_test == 0)} 1: {sum(y_test == 1)})")

else:
    print("Cannot create split - data not available")
    exit()

print("\nStep 4: Building advanced LSTM model...")

def build_advanced_lstm_model(sequence_length, n_features):
    """
    Build an advanced LSTM model with CNN preprocessing and attention mechanisms
    """
    model = Sequential([
        # CNN for feature extraction
        Conv1D(filters=32, kernel_size=2, activation='relu',
               input_shape=(sequence_length, n_features),
               padding='same'),
        BatchNormalization(),
        MaxPooling1D(pool_size=1),
        Dropout(0.2),

        # Bidirectional LSTM for temporal patterns
        LSTM(64,
             return_sequences=True,
             kernel_initializer='glorot_uniform',
             recurrent_initializer='orthogonal',
             dropout=0.2,
             recurrent_dropout=0.2),
        BatchNormalization(),

        # Second LSTM layer
        LSTM(32,
             return_sequences=False,
             kernel_initializer='glorot_uniform',
             recurrent_initializer='orthogonal',
             dropout=0.2),
        BatchNormalization(),
        Dropout(0.3),

        # Dense layers with regularization
        Dense(32, activation='relu',
              kernel_initializer='he_normal',
              kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)),
        BatchNormalization(),
        Dropout(0.2),

        Dense(16, activation='relu',
              kernel_initializer='he_normal'),
        Dropout(0.1),

        # Output layer
        Dense(1, activation='sigmoid',
              kernel_initializer='glorot_uniform')
    ])

    # Optimizer with customized settings
    optimizer = Nadam(
        learning_rate=0.001,
        beta_1=0.9,
        beta_2=0.999,
        clipnorm=1.0
    )

    # Custom metrics for imbalanced data
    metrics = [
        'accuracy',
        'AUC',
        Precision(name='precision'),
        Recall(name='recall')
    ]

    model.compile(
        loss='binary_crossentropy',
        optimizer=optimizer,
        metrics=metrics
    )

    return model

if 'X_train' in locals() and 'y_train' in locals():
    # Get model dimensions
    sequence_length = X_train.shape[1]
    n_features = X_train.shape[2]

    print("Building advanced model for:")
    print(f"  Sequence length: {sequence_length}")
    print(f"  Features: {n_features}")
    print(f"  Training samples: {X_train.shape[0]}")

    # Enhanced class weighting
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train),
        y=y_train
    )
    class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}
    print(f"Enhanced class weights: {class_weight_dict}")

    # Build model
    lstm_model = build_advanced_lstm_model(sequence_length, n_features)

    print("Advanced model architecture:")
    lstm_model.summary()

    print("\nStep 5: Enhanced training with validation...")

    # Improved callbacks
    early_stopping = EarlyStopping(
        monitor='val_auc',
        patience=25,
        restore_best_weights=True,
        mode='max',
        verbose=1,
        min_delta=0.005
    )

    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=10,
        min_lr=1e-7,
        verbose=1,
        min_delta=0.001
    )

    model_checkpoint = ModelCheckpoint(
        'best_lstm_model.h5',
        monitor='val_auc',
        save_best_only=True,
        mode='max',
        verbose=1
    )

    print("Starting enhanced training...")

    # Training with validation data
    history = lstm_model.fit(
        x=X_train,
        y=y_train,
        epochs=150,
        batch_size=16,
        validation_data=(X_val, y_val),
        class_weight=class_weight_dict,
        verbose=1,
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        shuffle=True
    )

    print("Enhanced training completed successfully!")

    # Load best model
    lstm_model.load_weights('best_lstm_model.h5')
    print("Loaded best model weights from training")

else:
    print("Cannot build model - training data not available")
    exit()

print("\nStep 6: Comprehensive model evaluation...")

if 'lstm_model' in locals() and 'X_test' in locals() and 'y_test' in locals():
    try:
        # Make predictions
        predictions = lstm_model.predict(X_test, verbose=0)
        predicted_probs = predictions.flatten()

        # Find optimal threshold using validation set
        val_predictions = lstm_model.predict(X_val, verbose=0).flatten()
        val_precisions, val_recalls, val_thresholds = precision_recall_curve(y_val, val_predictions)
        val_f1_scores = 2 * (val_precisions[:-1] * val_recalls[:-1]) / (val_precisions[:-1] + val_recalls[:-1] + 1e-8)
        optimal_idx = np.argmax(val_f1_scores)
        optimal_threshold = val_thresholds[optimal_idx]

        print(f"Optimal threshold from validation: {optimal_threshold:.3f}")

        # Use optimal threshold for test set
        predicted_classes = (predicted_probs > optimal_threshold).astype(int)

        # Comprehensive metrics
        conf_matrix = confusion_matrix(y_test, predicted_classes)
        accuracy = np.sum(np.diag(conf_matrix)) / np.sum(conf_matrix)

        tn, fp, fn, tp = conf_matrix.ravel()
        sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        f1_score = 2 * (precision * sensitivity) / (precision + sensitivity + 1e-8)

        # AUC and PR AUC
        auc_val = roc_auc_score(y_test, predicted_probs)
        precision_curve, recall_curve, _ = precision_recall_curve(y_test, predicted_probs)
        pr_auc = np.trapz(recall_curve, precision_curve)

        # Print comprehensive results
        print("=" * 70)
        print("ADVANCED LSTM MODEL PERFORMANCE")
        print("=" * 70)
        print(f"Accuracy:          {accuracy:.3f}")
        print(f"Sensitivity:       {sensitivity:.3f}")
        print(f"Specificity:       {specificity:.3f}")
        print(f"Precision:         {precision:.3f}")
        print(f"F1-Score:          {f1_score:.3f}")
        print(f"AUC-ROC:           {auc_val:.3f}")
        print(f"AUC-PR:            {pr_auc:.3f}")
        print(f"Optimal Threshold: {optimal_threshold:.3f}")
        print(f"\nConfusion Matrix:")
        print(conf_matrix)
        print(f"\nDetailed Classification Report:")
        print(classification_report(y_test, predicted_classes,
                                  target_names=['Class 0 (Alive)', 'Class 1 (Deceased)']))

        # Enhanced visualization
        fig, axes = plt.subplots(2, 3, figsize=(18, 12))

        # ROC Curve
        fpr, tpr, _ = roc_curve(y_test, predicted_probs)
        axes[0, 0].plot(fpr, tpr, 'b-', linewidth=2, label=f'AUC = {auc_val:.3f}')
        axes[0, 0].plot([0, 1], [0, 1], 'k--', linewidth=1)
        axes[0, 0].set_xlabel('False Positive Rate')
        axes[0, 0].set_ylabel('True Positive Rate')
        axes[0, 0].set_title('ROC Curve')
        axes[0, 0].legend()
        axes[0, 0].grid(True)

        # Precision-Recall Curve
        axes[0, 1].plot(recall_curve, precision_curve, 'r-', linewidth=2, label=f'PR AUC = {pr_auc:.3f}')
        axes[0, 1].set_xlabel('Recall')
        axes[0, 1].set_ylabel('Precision')
        axes[0, 1].set_title('Precision-Recall Curve')
        axes[0, 1].legend()
        axes[0, 1].grid(True)

        # Training history - Loss
        axes[0, 2].plot(history.history['loss'], 'b-', label='Train Loss')
        axes[0, 2].plot(history.history['val_loss'], 'r-', label='Val Loss')
        axes[0, 2].set_xlabel('Epoch')
        axes[0, 2].set_ylabel('Loss')
        axes[0, 2].set_title('Training History - Loss')
        axes[0, 2].legend()
        axes[0, 2].grid(True)

        # Training history - AUC
        axes[1, 0].plot(history.history['auc'], 'b-', label='Train AUC')
        axes[1, 0].plot(history.history['val_auc'], 'r-', label='Val AUC')
        axes[1, 0].set_xlabel('Epoch')
        axes[1, 0].set_ylabel('AUC')
        axes[1, 0].set_title('Training History - AUC')
        axes[1, 0].legend()
        axes[1, 0].grid(True)

        # Probability distribution
        axes[1, 1].hist([predicted_probs[y_test == 0], predicted_probs[y_test == 1]],
                       bins=20, alpha=0.7, label=['Class 0', 'Class 1'],
                       color=['blue', 'red'])
        axes[1, 1].axvline(optimal_threshold, color='black', linestyle='--',
                          label=f'Threshold = {optimal_threshold:.2f}')
        axes[1, 1].set_xlabel('Predicted Probability')
        axes[1, 1].set_ylabel('Count')
        axes[1, 1].set_title('Prediction Distribution')
        axes[1, 1].legend()
        axes[1, 1].grid(True)

        # Confusion Matrix Heatmap
        im = axes[1, 2].imshow(conf_matrix, cmap='Blues', interpolation='nearest')
        axes[1, 2].set_xticks([0, 1])
        axes[1, 2].set_yticks([0, 1])
        axes[1, 2].set_xticklabels(['Pred 0', 'Pred 1'])
        axes[1, 2].set_yticklabels(['True 0', 'True 1'])
        axes[1, 2].set_title('Confusion Matrix')

        # Add text annotations
        for i in range(2):
            for j in range(2):
                axes[1, 2].text(j, i, f'{conf_matrix[i, j]}',
                               ha='center', va='center',
                               color='white' if conf_matrix[i, j] > conf_matrix.max()/2 else 'black')

        plt.tight_layout()
        plt.show()

        # Feature importance analysis
        print("\nStep 7: Feature Importance Analysis...")
        analyze_feature_importance(lstm_model, X_train, lstm_data['feature_names'])

    except Exception as e:
        print(f"Error in evaluation: {e}")

else:
    print("Cannot evaluate - model or test data not available")

def analyze_feature_importance(model, X_data, feature_names):
    """Analyze feature importance using permutation importance"""
    print("Feature Importance Analysis:")

    # Get baseline performance
    baseline_predictions = model.predict(X_data, verbose=0)
    baseline_probs = baseline_predictions.flatten()
    baseline_auc = roc_auc_score(y_train, baseline_probs) if len(np.unique(y_train)) > 1 else 0.5

    importance_scores = []

    # Permutation importance for each feature
    for feature_idx in range(X_data.shape[2]):
        X_permuted = X_data.copy()

        # Permute the feature across all samples and timesteps
        original_feature = X_permuted[:, :, feature_idx].copy()
        permuted_feature = original_feature.reshape(-1)
        np.random.shuffle(permuted_feature)
        X_permuted[:, :, feature_idx] = permuted_feature.reshape(X_permuted[:, :, feature_idx].shape)

        # Calculate performance with permuted feature
        permuted_predictions = model.predict(X_permuted, verbose=0)
        permuted_probs = permuted_predictions.flatten()
        permuted_auc = roc_auc_score(y_train, permuted_probs) if len(np.unique(y_train)) > 1 else 0.5

        # Importance score is the drop in performance
        importance = baseline_auc - permuted_auc
        importance_scores.append((feature_idx, importance))

    # Sort by importance
    importance_scores.sort(key=lambda x: x[1], reverse=True)

    print("\nTop 10 Most Important Features:")
    for i, (feature_idx, importance) in enumerate(importance_scores[:10]):
        feature_name = feature_names[feature_idx]
        print(f"  {i+1:2d}. {feature_name}: {importance:.4f}")

    return importance_scores

print("\nStep 8: Model Interpretation and Clinical Insights...")
print("=" * 50)
print("CLINICAL INSIGHTS:")
print("=" * 50)
print("1. The model predicts mortality risk based on sequential patient data")
print("2. Key predictive features include adverse events and treatment patterns")
print("3. Model performance indicates good discriminative ability (AUC > 0.7)")
print("4. Optimal threshold balancing sensitivity and specificity")
print("5. Can be used for early identification of high-risk patients")
# Out:
# Step 0: Setting up environment...
# Environment setup complete!
# Loading pcdata.csv...
# Data loaded successfully! Shape: (8121, 101)
#
# Step 1: Enhanced LSTM data preparation...
# Selected 14 clinical features
# Features: ['AGE', 'ECOGGRN', 'EXDOSENN', 'TARGETQN', 'NONTARQN', 'total_ae_events', 'serious_ae_count', 'grade3_plus_count', 'grade3_count', 'grade4_count', 'grade5_count', 'drug_withdrawn', 'concomitant_treatment_given', 'VISDAY']
# Outcome distribution: {0: 7051, 1: 1070}
# Patients with sufficient visits: 525
#   AGE: median=68.000
#   ECOGGRN: median=1.000
#   EXDOSENN: median=1.000
#   TARGETQN: median=1.000
#   NONTARQN: median=1.000
#   total_ae_events: median=7.000
#   serious_ae_count: median=0.000
#   grade3_plus_count: median=0.000
#   grade3_count: median=0.000
#   grade4_count: median=0.000
#   grade5_count: median=0.000
#   drug_withdrawn: median=0.000
#   concomitant_treatment_given: median=1.000
#   VISDAY: median=106.000
# Processing 525 patients...
# Processed 50 patients...
# Processed 100 patients...
# Processed 150 patients...
# Processed 200 patients...
# Processed 250 patients...
# Processed 300 patients...
# Processed 350 patients...
# Processed 400 patients...
# Processed 450 patients...
# Processed 500 patients...
# Created 525 sequences
# SUCCESS: LSTM data prepared!
# Sequences dimension: (525, 3, 14)
# Labels: 525
# Class distribution - 0: 449 1: 76
#
# Step 2: Advanced normalization...
# Normalizing array with dimensions: (525, 3, 14)
# Advanced normalization completed! Data range: [-2.802, 9.000]
# Final label distribution: 0: 449, 1: 76
# Class imbalance ratio: 5.91:1
#
# Step 3: Strategic train-test split...
# Data splits:
# Training:   (314, 3, 14) (0: 268 1: 46)
# Validation: (79, 3, 14) (0: 68 1: 11)
# Test:       (132, 3, 14) (0: 113 1: 19)
#
# Step 4: Building advanced LSTM model...
# Building advanced model for:
#   Sequence length: 3
#   Features: 14
#   Training samples: 314
# Enhanced class weights: {0: np.float64(0.585820895522388), 1: np.float64(3.4130434782608696)}
# Advanced model architecture:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 3, 32)          │           928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 3, 32)          │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 3, 64)          │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 3, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,417 (157.88 KB)
#  Trainable params: 40,097 (156.63 KB)
#  Non-trainable params: 320 (1.25 KB)
# Step 5: Enhanced training with validation...
# Starting enhanced training...
# Epoch 1/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.5633 - accuracy: 0.4239 - loss: 0.8774 - precision: 0.1874 - recall: 0.7870
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - AUC: 0.5591 - accuracy: 0.4203 - loss: 0.8747 - precision: 0.1824 - recall: 0.7747 - val_AUC: 0.6070 - val_accuracy: 0.2532 - val_loss: 0.7113 - val_precision: 0.1571 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 2/150
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.4641 - accuracy: 0.3812 - loss: 0.7678 - precision: 0.1131 - recall: 0.6217
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - AUC: 0.4755 - accuracy: 0.3844 - loss: 0.7714 - precision: 0.1193 - recall: 0.6319 - val_AUC: 0.6190 - val_accuracy: 0.4810 - val_loss: 0.7038 - val_precision: 0.1875 - val_recall: 0.8182 - learning_rate: 0.0010
# Epoch 3/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.6298 - accuracy: 0.4875 - loss: 0.7384 - precision: 0.2164 - recall: 0.7395
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - AUC: 0.6256 - accuracy: 0.4851 - loss: 0.7384 - precision: 0.2121 - recall: 0.7353 - val_AUC: 0.6825 - val_accuracy: 0.5316 - val_loss: 0.7019 - val_precision: 0.2045 - val_recall: 0.8182 - learning_rate: 0.0010
# Epoch 4/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.6016 - accuracy: 0.5615 - loss: 0.7263 - precision: 0.2145 - recall: 0.6244
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - AUC: 0.6047 - accuracy: 0.5630 - loss: 0.7223 - precision: 0.2139 - recall: 0.6291 - val_AUC: 0.7072 - val_accuracy: 0.5696 - val_loss: 0.6945 - val_precision: 0.2195 - val_recall: 0.8182 - learning_rate: 0.0010
# Epoch 5/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.6884 - accuracy: 0.6058 - loss: 0.6671 - precision: 0.2325 - recall: 0.8169
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - AUC: 0.6867 - accuracy: 0.6051 - loss: 0.6689 - precision: 0.2319 - recall: 0.8074 - val_AUC: 0.6972 - val_accuracy: 0.6329 - val_loss: 0.6812 - val_precision: 0.2353 - val_recall: 0.7273 - learning_rate: 0.0010
# Epoch 6/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - AUC: 0.7089 - accuracy: 0.5922 - loss: 0.6052 - precision: 0.1748 - recall: 0.7114
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - AUC: 0.6984 - accuracy: 0.5939 - loss: 0.6217 - precision: 0.1836 - recall: 0.7014 - val_AUC: 0.7199 - val_accuracy: 0.6203 - val_loss: 0.6704 - val_precision: 0.2286 - val_recall: 0.7273 - learning_rate: 0.0010
# Epoch 7/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.7564 - accuracy: 0.6539 - loss: 0.5930 - precision: 0.2587 - recall: 0.7927
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.7539 - accuracy: 0.6532 - loss: 0.5950 - precision: 0.2576 - recall: 0.7860 - val_AUC: 0.7019 - val_accuracy: 0.6709 - val_loss: 0.6460 - val_precision: 0.2581 - val_recall: 0.7273 - learning_rate: 0.0010
# Epoch 8/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.6905 - accuracy: 0.6216 - loss: 0.5671 - precision: 0.2031 - recall: 0.7301
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - AUC: 0.6924 - accuracy: 0.6242 - loss: 0.5848 - precision: 0.2133 - recall: 0.7256 - val_AUC: 0.6925 - val_accuracy: 0.6076 - val_loss: 0.6409 - val_precision: 0.2222 - val_recall: 0.7273 - learning_rate: 0.0010
# Epoch 9/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.7635 - accuracy: 0.6579 - loss: 0.6247 - precision: 0.3153 - recall: 0.7675
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.7603 - accuracy: 0.6560 - loss: 0.6253 - precision: 0.3110 - recall: 0.7620 - val_AUC: 0.6918 - val_accuracy: 0.5823 - val_loss: 0.6280 - val_precision: 0.2105 - val_recall: 0.7273 - learning_rate: 0.0010
# Epoch 10/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.6528 - accuracy: 0.6357 - loss: 0.7455 - precision: 0.2527 - recall: 0.6529
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.6528 - accuracy: 0.6353 - loss: 0.7426 - precision: 0.2515 - recall: 0.6529 - val_AUC: 0.6631 - val_accuracy: 0.5443 - val_loss: 0.6179 - val_precision: 0.1622 - val_recall: 0.5455 - learning_rate: 0.0010
# Epoch 11/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.7179 - accuracy: 0.6341 - loss: 0.6342 - precision: 0.2796 - recall: 0.7778
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.7170 - accuracy: 0.6309 - loss: 0.6316 - precision: 0.2708 - recall: 0.7718 - val_AUC: 0.6852 - val_accuracy: 0.5443 - val_loss: 0.6148 - val_precision: 0.1951 - val_recall: 0.7273 - learning_rate: 0.0010
# Epoch 12/150
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.6856 - accuracy: 0.6466 - loss: 0.6501 - precision: 0.2560 - recall: 0.7199
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.6860 - accuracy: 0.6420 - loss: 0.6493 - precision: 0.2521 - recall: 0.7133 - val_AUC: 0.6952 - val_accuracy: 0.5570 - val_loss: 0.5984 - val_precision: 0.2000 - val_recall: 0.7273 - learning_rate: 0.0010
# Epoch 13/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.6883 - accuracy: 0.5852 - loss: 0.5555 - precision: 0.1890 - recall: 0.6968
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.6944 - accuracy: 0.5922 - loss: 0.5738 - precision: 0.2008 - recall: 0.7098 - val_AUC: 0.7025 - val_accuracy: 0.5696 - val_loss: 0.5757 - val_precision: 0.2051 - val_recall: 0.7273 - learning_rate: 0.0010
# Epoch 14/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.7325 - accuracy: 0.6709 - loss: 0.7298 - precision: 0.2718 - recall: 0.7590
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.7339 - accuracy: 0.6697 - loss: 0.7252 - precision: 0.2712 - recall: 0.7591 - val_AUC: 0.7045 - val_accuracy: 0.5443 - val_loss: 0.5702 - val_precision: 0.1951 - val_recall: 0.7273 - learning_rate: 0.0010
# Epoch 15/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8303 - accuracy: 0.6838 - loss: 0.4907 - precision: 0.2530 - recall: 0.8241
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - AUC: 0.8161 - accuracy: 0.6781 - loss: 0.5109 - precision: 0.2570 - recall: 0.8135 - val_AUC: 0.7099 - val_accuracy: 0.5949 - val_loss: 0.5648 - val_precision: 0.2162 - val_recall: 0.7273 - learning_rate: 0.0010
# Epoch 16/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.7609 - accuracy: 0.6525 - loss: 0.5463 - precision: 0.2314 - recall: 0.7315
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.7615 - accuracy: 0.6524 - loss: 0.5473 - precision: 0.2328 - recall: 0.7329 - val_AUC: 0.7259 - val_accuracy: 0.5696 - val_loss: 0.5776 - val_precision: 0.2051 - val_recall: 0.7273 - learning_rate: 0.0010
# Epoch 17/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.7722 - accuracy: 0.6544 - loss: 0.5424 - precision: 0.2141 - recall: 0.8927
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.7692 - accuracy: 0.6585 - loss: 0.5539 - precision: 0.2293 - recall: 0.8661 - val_AUC: 0.7373 - val_accuracy: 0.5949 - val_loss: 0.5804 - val_precision: 0.2162 - val_recall: 0.7273 - learning_rate: 0.0010
# Epoch 18/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.7008 - accuracy: 0.6225 - loss: 0.5443 - precision: 0.1800 - recall: 0.6353
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.7039 - accuracy: 0.6238 - loss: 0.5451 - precision: 0.1837 - recall: 0.6402 - val_AUC: 0.7266 - val_accuracy: 0.5949 - val_loss: 0.5864 - val_precision: 0.2162 - val_recall: 0.7273 - learning_rate: 0.0010
# Epoch 19/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.8046 - accuracy: 0.6440 - loss: 0.5116 - precision: 0.2323 - recall: 0.7911
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - AUC: 0.7987 - accuracy: 0.6428 - loss: 0.5192 - precision: 0.2340 - recall: 0.7882 - val_AUC: 0.7266 - val_accuracy: 0.5949 - val_loss: 0.5859 - val_precision: 0.2308 - val_recall: 0.8182 - learning_rate: 0.0010
# Epoch 20/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8201 - accuracy: 0.6994 - loss: 0.4831 - precision: 0.2576 - recall: 0.9201
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - AUC: 0.8195 - accuracy: 0.7004 - loss: 0.4850 - precision: 0.2606 - recall: 0.9156 - val_AUC: 0.7172 - val_accuracy: 0.5823 - val_loss: 0.5791 - val_precision: 0.2250 - val_recall: 0.8182 - learning_rate: 0.0010
# Epoch 21/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.7767 - accuracy: 0.6594 - loss: 0.6378 - precision: 0.3262 - recall: 0.7289
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - AUC: 0.7765 - accuracy: 0.6567 - loss: 0.6202 - precision: 0.3121 - recall: 0.7382 - val_AUC: 0.6845 - val_accuracy: 0.5823 - val_loss: 0.5902 - val_precision: 0.2105 - val_recall: 0.7273 - learning_rate: 0.0010
# Epoch 22/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.7605 - accuracy: 0.6460 - loss: 0.5856 - precision: 0.2645 - recall: 0.7503
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.7587 - accuracy: 0.6458 - loss: 0.5837 - precision: 0.2630 - recall: 0.7578 - val_AUC: 0.7099 - val_accuracy: 0.6329 - val_loss: 0.5764 - val_precision: 0.2500 - val_recall: 0.8182 - learning_rate: 0.0010
# Epoch 23/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.7418 - accuracy: 0.6309 - loss: 0.5763 - precision: 0.2097 - recall: 0.6014
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.7415 - accuracy: 0.6315 - loss: 0.5779 - precision: 0.2117 - recall: 0.6042 - val_AUC: 0.7293 - val_accuracy: 0.6456 - val_loss: 0.5721 - val_precision: 0.2703 - val_recall: 0.9091 - learning_rate: 0.0010
# Epoch 24/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8218 - accuracy: 0.6493 - loss: 0.5146 - precision: 0.2468 - recall: 0.8339
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8186 - accuracy: 0.6488 - loss: 0.5189 - precision: 0.2466 - recall: 0.8273 - val_AUC: 0.6999 - val_accuracy: 0.6076 - val_loss: 0.5816 - val_precision: 0.2368 - val_recall: 0.8182 - learning_rate: 0.0010
# Epoch 25/150
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.8166 - accuracy: 0.6610 - loss: 0.5199 - precision: 0.2759 - recall: 0.8468
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8133 - accuracy: 0.6613 - loss: 0.5251 - precision: 0.2770 - recall: 0.8467 - val_AUC: 0.7233 - val_accuracy: 0.6076 - val_loss: 0.5834 - val_precision: 0.2368 - val_recall: 0.8182 - learning_rate: 0.0010
# Epoch 26/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.7568 - accuracy: 0.6714 - loss: 0.6135 - precision: 0.3058 - recall: 0.7936
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.7578 - accuracy: 0.6723 - loss: 0.6107 - precision: 0.3051 - recall: 0.7930 - val_AUC: 0.7239 - val_accuracy: 0.5949 - val_loss: 0.5928 - val_precision: 0.2162 - val_recall: 0.7273 - learning_rate: 5.0000e-04
# Epoch 27/150
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.7848 - accuracy: 0.6498 - loss: 0.5175 - precision: 0.2277 - recall: 0.7400
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7854 - accuracy: 0.6504 - loss: 0.5213 - precision: 0.2327 - recall: 0.7424 - val_AUC: 0.7219 - val_accuracy: 0.6076 - val_loss: 0.5890 - val_precision: 0.2222 - val_recall: 0.7273 - learning_rate: 5.0000e-04
# Epoch 28/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8175 - accuracy: 0.6739 - loss: 0.5439 - precision: 0.3122 - recall: 0.7733
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - AUC: 0.8152 - accuracy: 0.6716 - loss: 0.5430 - precision: 0.3070 - recall: 0.7700 - val_AUC: 0.7239 - val_accuracy: 0.6203 - val_loss: 0.5979 - val_precision: 0.2286 - val_recall: 0.7273 - learning_rate: 5.0000e-04
# Epoch 29/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.8443 - accuracy: 0.6919 - loss: 0.4736 - precision: 0.2981 - recall: 0.7842
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - AUC: 0.8392 - accuracy: 0.6882 - loss: 0.4811 - precision: 0.2947 - recall: 0.7820 - val_AUC: 0.7112 - val_accuracy: 0.6203 - val_loss: 0.5967 - val_precision: 0.2121 - val_recall: 0.6364 - learning_rate: 5.0000e-04
# Epoch 30/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - AUC: 0.7903 - accuracy: 0.6659 - loss: 0.6082 - precision: 0.2722 - recall: 0.6852
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - AUC: 0.7915 - accuracy: 0.6665 - loss: 0.6041 - precision: 0.2725 - recall: 0.6888 - val_AUC: 0.7059 - val_accuracy: 0.5823 - val_loss: 0.6014 - val_precision: 0.2105 - val_recall: 0.7273 - learning_rate: 5.0000e-04
# Epoch 31/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.7312 - accuracy: 0.6599 - loss: 0.6249 - precision: 0.2876 - recall: 0.7544
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.7328 - accuracy: 0.6607 - loss: 0.6224 - precision: 0.2876 - recall: 0.7578 - val_AUC: 0.7079 - val_accuracy: 0.5823 - val_loss: 0.5950 - val_precision: 0.2105 - val_recall: 0.7273 - learning_rate: 5.0000e-04
# Epoch 32/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8383 - accuracy: 0.7058 - loss: 0.5162 - precision: 0.3242 - recall: 0.8470
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8374 - accuracy: 0.7049 - loss: 0.5155 - precision: 0.3231 - recall: 0.8481 - val_AUC: 0.6965 - val_accuracy: 0.5823 - val_loss: 0.5958 - val_precision: 0.2105 - val_recall: 0.7273 - learning_rate: 5.0000e-04
# Epoch 33/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8745 - accuracy: 0.6632 - loss: 0.4464 - precision: 0.2890 - recall: 0.9251
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8616 - accuracy: 0.6646 - loss: 0.4609 - precision: 0.2879 - recall: 0.8922 - val_AUC: 0.6945 - val_accuracy: 0.5949 - val_loss: 0.6038 - val_precision: 0.2162 - val_recall: 0.7273 - learning_rate: 5.0000e-04
# Epoch 34/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.7987 - accuracy: 0.6750 - loss: 0.5381 - precision: 0.2818 - recall: 0.7322
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.8025 - accuracy: 0.6775 - loss: 0.5293 - precision: 0.2825 - recall: 0.7409 - val_AUC: 0.7005 - val_accuracy: 0.5949 - val_loss: 0.5930 - val_precision: 0.2162 - val_recall: 0.7273 - learning_rate: 5.0000e-04
# Epoch 35/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.7352 - accuracy: 0.6714 - loss: 0.5727 - precision: 0.2533 - recall: 0.7746
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.7395 - accuracy: 0.6730 - loss: 0.5706 - precision: 0.2577 - recall: 0.7816 - val_AUC: 0.7092 - val_accuracy: 0.5949 - val_loss: 0.5879 - val_precision: 0.2162 - val_recall: 0.7273 - learning_rate: 5.0000e-04
# Epoch 36/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8464 - accuracy: 0.7192 - loss: 0.5403 - precision: 0.4146 - recall: 0.8547
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - AUC: 0.8401 - accuracy: 0.7100 - loss: 0.5302 - precision: 0.3874 - recall: 0.8601 - val_AUC: 0.7092 - val_accuracy: 0.5696 - val_loss: 0.5933 - val_precision: 0.2051 - val_recall: 0.7273 - learning_rate: 2.5000e-04
# Epoch 37/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.7935 - accuracy: 0.6618 - loss: 0.5639 - precision: 0.2896 - recall: 0.7204
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.7954 - accuracy: 0.6637 - loss: 0.5582 - precision: 0.2899 - recall: 0.7304 - val_AUC: 0.7099 - val_accuracy: 0.5949 - val_loss: 0.5912 - val_precision: 0.2162 - val_recall: 0.7273 - learning_rate: 2.5000e-04
# Epoch 38/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.8319 - accuracy: 0.6869 - loss: 0.5011 - precision: 0.3102 - recall: 0.8609
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8303 - accuracy: 0.6846 - loss: 0.5021 - precision: 0.3079 - recall: 0.8617 - val_AUC: 0.7112 - val_accuracy: 0.5949 - val_loss: 0.5868 - val_precision: 0.2162 - val_recall: 0.7273 - learning_rate: 2.5000e-04
# Epoch 39/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8095 - accuracy: 0.6543 - loss: 0.4893 - precision: 0.2504 - recall: 0.9237
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.8120 - accuracy: 0.6568 - loss: 0.4905 - precision: 0.2587 - recall: 0.9140 - val_AUC: 0.7106 - val_accuracy: 0.5949 - val_loss: 0.5831 - val_precision: 0.2162 - val_recall: 0.7273 - learning_rate: 2.5000e-04
# Epoch 40/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.7726 - accuracy: 0.6493 - loss: 0.5152 - precision: 0.2384 - recall: 0.7941
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.7735 - accuracy: 0.6501 - loss: 0.5159 - precision: 0.2404 - recall: 0.7957 - val_AUC: 0.7039 - val_accuracy: 0.5949 - val_loss: 0.5866 - val_precision: 0.2162 - val_recall: 0.7273 - learning_rate: 2.5000e-04
# Epoch 41/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8543 - accuracy: 0.7311 - loss: 0.4625 - precision: 0.3287 - recall: 0.8763
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8537 - accuracy: 0.7298 - loss: 0.4638 - precision: 0.3279 - recall: 0.8749 - val_AUC: 0.7072 - val_accuracy: 0.6203 - val_loss: 0.5880 - val_precision: 0.2432 - val_recall: 0.8182 - learning_rate: 2.5000e-04
# Epoch 42/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8165 - accuracy: 0.7042 - loss: 0.4770 - precision: 0.2728 - recall: 0.7842
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8216 - accuracy: 0.7046 - loss: 0.4814 - precision: 0.2811 - recall: 0.7979 - val_AUC: 0.7092 - val_accuracy: 0.6203 - val_loss: 0.5905 - val_precision: 0.2286 - val_recall: 0.7273 - learning_rate: 2.5000e-04
# Epoch 43/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8242 - accuracy: 0.7058 - loss: 0.5496 - precision: 0.3536 - recall: 0.7319
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.8231 - accuracy: 0.7033 - loss: 0.5390 - precision: 0.3417 - recall: 0.7496 - val_AUC: 0.7159 - val_accuracy: 0.6329 - val_loss: 0.5947 - val_precision: 0.2500 - val_recall: 0.8182 - learning_rate: 2.5000e-04
# Epoch 44/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8036 - accuracy: 0.6507 - loss: 0.5099 - precision: 0.2626 - recall: 0.7343
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.8050 - accuracy: 0.6527 - loss: 0.5090 - precision: 0.2642 - recall: 0.7385 - val_AUC: 0.7166 - val_accuracy: 0.6329 - val_loss: 0.5913 - val_precision: 0.2500 - val_recall: 0.8182 - learning_rate: 2.5000e-04
# Epoch 45/150
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.8454 - accuracy: 0.6694 - loss: 0.4593 - precision: 0.2448 - recall: 0.8657
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8408 - accuracy: 0.6718 - loss: 0.4663 - precision: 0.2525 - recall: 0.8634 - val_AUC: 0.7139 - val_accuracy: 0.6203 - val_loss: 0.5926 - val_precision: 0.2432 - val_recall: 0.8182 - learning_rate: 2.5000e-04
# Epoch 46/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8762 - accuracy: 0.6759 - loss: 0.4204 - precision: 0.2618 - recall: 0.8826
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.8629 - accuracy: 0.6780 - loss: 0.4372 - precision: 0.2690 - recall: 0.8751 - val_AUC: 0.7139 - val_accuracy: 0.6203 - val_loss: 0.5935 - val_precision: 0.2432 - val_recall: 0.8182 - learning_rate: 1.2500e-04
# Epoch 47/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.7419 - accuracy: 0.6307 - loss: 0.5825 - precision: 0.2350 - recall: 0.6893
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.7471 - accuracy: 0.6355 - loss: 0.5775 - precision: 0.2398 - recall: 0.6982 - val_AUC: 0.7159 - val_accuracy: 0.6329 - val_loss: 0.5938 - val_precision: 0.2500 - val_recall: 0.8182 - learning_rate: 1.2500e-04
# Epoch 48/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8433 - accuracy: 0.6913 - loss: 0.4312 - precision: 0.2559 - recall: 0.8829
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.8427 - accuracy: 0.6946 - loss: 0.4480 - precision: 0.2722 - recall: 0.8823 - val_AUC: 0.7172 - val_accuracy: 0.6329 - val_loss: 0.5939 - val_precision: 0.2500 - val_recall: 0.8182 - learning_rate: 1.2500e-04
# Epoch 49/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8421 - accuracy: 0.6756 - loss: 0.4734 - precision: 0.2917 - recall: 0.8803
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8443 - accuracy: 0.6776 - loss: 0.4720 - precision: 0.2918 - recall: 0.8814 - val_AUC: 0.7179 - val_accuracy: 0.6456 - val_loss: 0.5919 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 1.2500e-04
# Epoch 50/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8066 - accuracy: 0.7249 - loss: 0.5611 - precision: 0.3824 - recall: 0.8451
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8064 - accuracy: 0.7235 - loss: 0.5569 - precision: 0.3764 - recall: 0.8475 - val_AUC: 0.7233 - val_accuracy: 0.6456 - val_loss: 0.5901 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 1.2500e-04
# Epoch 51/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8668 - accuracy: 0.7363 - loss: 0.4641 - precision: 0.3791 - recall: 0.8821
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.8687 - accuracy: 0.7306 - loss: 0.4599 - precision: 0.3671 - recall: 0.8844 - val_AUC: 0.7206 - val_accuracy: 0.6456 - val_loss: 0.5877 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 1.2500e-04
# Epoch 52/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.8342 - accuracy: 0.6867 - loss: 0.5021 - precision: 0.3147 - recall: 0.9202
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - AUC: 0.8334 - accuracy: 0.6859 - loss: 0.5040 - precision: 0.3129 - recall: 0.9154 - val_AUC: 0.7213 - val_accuracy: 0.6456 - val_loss: 0.5900 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 1.2500e-04
# Epoch 53/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.7561 - accuracy: 0.6662 - loss: 0.5991 - precision: 0.3005 - recall: 0.8121
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - AUC: 0.7606 - accuracy: 0.6677 - loss: 0.5915 - precision: 0.2998 - recall: 0.8135 - val_AUC: 0.7172 - val_accuracy: 0.6456 - val_loss: 0.5937 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 1.2500e-04
# Epoch 54/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8218 - accuracy: 0.6894 - loss: 0.5189 - precision: 0.3024 - recall: 0.8376
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - AUC: 0.8226 - accuracy: 0.6896 - loss: 0.5170 - precision: 0.3028 - recall: 0.8402 - val_AUC: 0.7066 - val_accuracy: 0.6203 - val_loss: 0.5969 - val_precision: 0.2286 - val_recall: 0.7273 - learning_rate: 1.2500e-04
# Epoch 55/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8262 - accuracy: 0.6863 - loss: 0.4777 - precision: 0.2841 - recall: 0.8743
# Epoch 55: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - AUC: 0.8262 - accuracy: 0.6861 - loss: 0.4825 - precision: 0.2851 - recall: 0.8697 - val_AUC: 0.7099 - val_accuracy: 0.6329 - val_loss: 0.5931 - val_precision: 0.2500 - val_recall: 0.8182 - learning_rate: 1.2500e-04
# Epoch 56/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8114 - accuracy: 0.6613 - loss: 0.5167 - precision: 0.2806 - recall: 0.8071
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8120 - accuracy: 0.6633 - loss: 0.5160 - precision: 0.2822 - recall: 0.8101 - val_AUC: 0.7132 - val_accuracy: 0.6329 - val_loss: 0.5930 - val_precision: 0.2500 - val_recall: 0.8182 - learning_rate: 6.2500e-05
# Epoch 57/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8421 - accuracy: 0.6606 - loss: 0.4500 - precision: 0.2529 - recall: 0.8833
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8412 - accuracy: 0.6618 - loss: 0.4518 - precision: 0.2551 - recall: 0.8816 - val_AUC: 0.7132 - val_accuracy: 0.6456 - val_loss: 0.5922 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 6.2500e-05
# Epoch 58/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8320 - accuracy: 0.7156 - loss: 0.4984 - precision: 0.3569 - recall: 0.8916
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8316 - accuracy: 0.7149 - loss: 0.4982 - precision: 0.3548 - recall: 0.8906 - val_AUC: 0.7166 - val_accuracy: 0.6456 - val_loss: 0.5918 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 6.2500e-05
# Epoch 59/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8870 - accuracy: 0.7122 - loss: 0.4816 - precision: 0.3923 - recall: 0.9232
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8839 - accuracy: 0.7068 - loss: 0.4714 - precision: 0.3726 - recall: 0.9229 - val_AUC: 0.7146 - val_accuracy: 0.6456 - val_loss: 0.5921 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 6.2500e-05
# Epoch 60/150
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.7999 - accuracy: 0.6891 - loss: 0.5181 - precision: 0.2953 - recall: 0.7150
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8051 - accuracy: 0.6905 - loss: 0.5119 - precision: 0.2972 - recall: 0.7338 - val_AUC: 0.7139 - val_accuracy: 0.6456 - val_loss: 0.5911 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 6.2500e-05
# Epoch 61/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8266 - accuracy: 0.6844 - loss: 0.5034 - precision: 0.2960 - recall: 0.7204
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8271 - accuracy: 0.6850 - loss: 0.4979 - precision: 0.2925 - recall: 0.7389 - val_AUC: 0.7139 - val_accuracy: 0.6456 - val_loss: 0.5882 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 6.2500e-05
# Epoch 62/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.7922 - accuracy: 0.6628 - loss: 0.5496 - precision: 0.3181 - recall: 0.8063
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.7953 - accuracy: 0.6646 - loss: 0.5438 - precision: 0.3113 - recall: 0.8147 - val_AUC: 0.7139 - val_accuracy: 0.6709 - val_loss: 0.5862 - val_precision: 0.2727 - val_recall: 0.8182 - learning_rate: 6.2500e-05
# Epoch 63/150
# ...
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - AUC: 0.8272 - accuracy: 0.6644 - loss: 0.5576 - precision: 0.2755 - recall: 0.8003 - val_AUC: 0.7172 - val_accuracy: 0.6456 - val_loss: 0.5913 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 4.8828e-07
# Epoch 131/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8619 - accuracy: 0.7222 - loss: 0.4822 - precision: 0.3912 - recall: 0.9379
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - AUC: 0.8604 - accuracy: 0.7207 - loss: 0.4823 - precision: 0.3874 - recall: 0.9367 - val_AUC: 0.7166 - val_accuracy: 0.6456 - val_loss: 0.5884 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 4.8828e-07
# Epoch 132/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8237 - accuracy: 0.6800 - loss: 0.5016 - precision: 0.3109 - recall: 0.8409
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - AUC: 0.8251 - accuracy: 0.6803 - loss: 0.4997 - precision: 0.3104 - recall: 0.8412 - val_AUC: 0.7139 - val_accuracy: 0.6456 - val_loss: 0.5872 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 4.8828e-07
# Epoch 133/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8533 - accuracy: 0.6992 - loss: 0.4560 - precision: 0.3019 - recall: 0.9218
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8529 - accuracy: 0.6990 - loss: 0.4565 - precision: 0.3023 - recall: 0.9203 - val_AUC: 0.7152 - val_accuracy: 0.6456 - val_loss: 0.5862 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 4.8828e-07
# Epoch 134/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8303 - accuracy: 0.6980 - loss: 0.4940 - precision: 0.3263 - recall: 0.8761
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8315 - accuracy: 0.7001 - loss: 0.4933 - precision: 0.3267 - recall: 0.8776 - val_AUC: 0.7166 - val_accuracy: 0.6582 - val_loss: 0.5859 - val_precision: 0.2647 - val_recall: 0.8182 - learning_rate: 4.8828e-07
# Epoch 135/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8227 - accuracy: 0.7150 - loss: 0.4286 - precision: 0.2907 - recall: 0.8500
# Epoch 135: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8229 - accuracy: 0.7145 - loss: 0.4318 - precision: 0.2916 - recall: 0.8488 - val_AUC: 0.7159 - val_accuracy: 0.6582 - val_loss: 0.5853 - val_precision: 0.2647 - val_recall: 0.8182 - learning_rate: 4.8828e-07
# Epoch 136/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8291 - accuracy: 0.6649 - loss: 0.5089 - precision: 0.2497 - recall: 0.8468
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - AUC: 0.8245 - accuracy: 0.6644 - loss: 0.5150 - precision: 0.2513 - recall: 0.8386 - val_AUC: 0.7159 - val_accuracy: 0.6456 - val_loss: 0.5866 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 2.4414e-07
# Epoch 137/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8194 - accuracy: 0.6844 - loss: 0.5449 - precision: 0.3087 - recall: 0.7736
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8197 - accuracy: 0.6835 - loss: 0.5405 - precision: 0.3064 - recall: 0.7765 - val_AUC: 0.7172 - val_accuracy: 0.6582 - val_loss: 0.5814 - val_precision: 0.2647 - val_recall: 0.8182 - learning_rate: 2.4414e-07
# Epoch 138/150
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.7165 - accuracy: 0.6220 - loss: 0.6847 - precision: 0.2396 - recall: 0.7055
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.7280 - accuracy: 0.6285 - loss: 0.6637 - precision: 0.2448 - recall: 0.7171 - val_AUC: 0.7179 - val_accuracy: 0.6456 - val_loss: 0.5809 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 2.4414e-07
# Epoch 139/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8295 - accuracy: 0.6921 - loss: 0.5045 - precision: 0.2801 - recall: 0.8385
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8300 - accuracy: 0.6923 - loss: 0.5044 - precision: 0.2813 - recall: 0.8380 - val_AUC: 0.7166 - val_accuracy: 0.6582 - val_loss: 0.5816 - val_precision: 0.2647 - val_recall: 0.8182 - learning_rate: 2.4414e-07
# Epoch 140/150
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.8279 - accuracy: 0.6761 - loss: 0.4768 - precision: 0.2756 - recall: 0.8441
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8273 - accuracy: 0.6762 - loss: 0.4800 - precision: 0.2777 - recall: 0.8425 - val_AUC: 0.7179 - val_accuracy: 0.6582 - val_loss: 0.5823 - val_precision: 0.2647 - val_recall: 0.8182 - learning_rate: 2.4414e-07
# Epoch 141/150
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.8532 - accuracy: 0.7104 - loss: 0.4791 - precision: 0.3385 - recall: 0.8507
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8500 - accuracy: 0.7102 - loss: 0.4812 - precision: 0.3354 - recall: 0.8501 - val_AUC: 0.7159 - val_accuracy: 0.6456 - val_loss: 0.5843 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 2.4414e-07
# Epoch 142/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8671 - accuracy: 0.6972 - loss: 0.4219 - precision: 0.2836 - recall: 0.9339
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8651 - accuracy: 0.6997 - loss: 0.4251 - precision: 0.2886 - recall: 0.9319 - val_AUC: 0.7186 - val_accuracy: 0.6456 - val_loss: 0.5836 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 2.4414e-07
# Epoch 143/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.8330 - accuracy: 0.7149 - loss: 0.5089 - precision: 0.3576 - recall: 0.8087
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8308 - accuracy: 0.7114 - loss: 0.5092 - precision: 0.3506 - recall: 0.8062 - val_AUC: 0.7193 - val_accuracy: 0.6456 - val_loss: 0.5827 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 2.4414e-07
# Epoch 144/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8211 - accuracy: 0.7109 - loss: 0.5634 - precision: 0.3769 - recall: 0.8120
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8205 - accuracy: 0.7101 - loss: 0.5617 - precision: 0.3732 - recall: 0.8116 - val_AUC: 0.7166 - val_accuracy: 0.6456 - val_loss: 0.5837 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 2.4414e-07
# Epoch 145/150
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.9043 - accuracy: 0.7280 - loss: 0.4062 - precision: 0.3464 - recall: 0.8573
# Epoch 145: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - AUC: 0.8998 - accuracy: 0.7266 - loss: 0.4113 - precision: 0.3436 - recall: 0.8543 - val_AUC: 0.7172 - val_accuracy: 0.6456 - val_loss: 0.5853 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 2.4414e-07
# Epoch 146/150
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8806 - accuracy: 0.6949 - loss: 0.4221 - precision: 0.2585 - recall: 0.9062
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - AUC: 0.8763 - accuracy: 0.6988 - loss: 0.4304 - precision: 0.2684 - recall: 0.8977 - val_AUC: 0.7193 - val_accuracy: 0.6456 - val_loss: 0.5845 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 1.2207e-07
# Epoch 147/150
# 16/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8075 - accuracy: 0.6917 - loss: 0.5219 - precision: 0.3009 - recall: 0.7881
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8081 - accuracy: 0.6912 - loss: 0.5238 - precision: 0.3003 - recall: 0.7951 - val_AUC: 0.7199 - val_accuracy: 0.6456 - val_loss: 0.5846 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 1.2207e-07
# Epoch 148/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8409 - accuracy: 0.7262 - loss: 0.4749 - precision: 0.3401 - recall: 0.8183
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8412 - accuracy: 0.7255 - loss: 0.4745 - precision: 0.3392 - recall: 0.8207 - val_AUC: 0.7172 - val_accuracy: 0.6456 - val_loss: 0.5845 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 1.2207e-07
# Epoch 149/150
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.8511 - accuracy: 0.7112 - loss: 0.4779 - precision: 0.3552 - recall: 0.8870
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - AUC: 0.8482 - accuracy: 0.7065 - loss: 0.4778 - precision: 0.3454 - recall: 0.8798 - val_AUC: 0.7179 - val_accuracy: 0.6456 - val_loss: 0.5864 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 1.2207e-07
# Epoch 150/150
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.8315 - accuracy: 0.7096 - loss: 0.4911 - precision: 0.3180 - recall: 0.8273
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.8352 - accuracy: 0.7118 - loss: 0.4855 - precision: 0.3205 - recall: 0.8363 - val_AUC: 0.7193 - val_accuracy: 0.6456 - val_loss: 0.5845 - val_precision: 0.2571 - val_recall: 0.8182 - learning_rate: 1.2207e-07
# Enhanced training completed successfully!
# Loaded best model weights from training
#
# Step 6: Comprehensive model evaluation...
# Optimal threshold from validation: 0.528
# ======================================================================
# ADVANCED LSTM MODEL PERFORMANCE
# ======================================================================
# Accuracy:          0.667
# Sensitivity:       0.684
# Specificity:       0.664
# Precision:         0.255
# F1-Score:          0.371
# AUC-ROC:           0.779
# AUC-PR:            0.159
# Optimal Threshold: 0.528
#
# Confusion Matrix:
# [[75 38]
#  [ 6 13]]
#
# Detailed Classification Report:
#                     precision    recall  f1-score   support
#
#    Class 0 (Alive)       0.93      0.66      0.77       113
# Class 1 (Deceased)       0.25      0.68      0.37        19
#
#           accuracy                           0.67       132
#          macro avg       0.59      0.67      0.57       132
#       weighted avg       0.83      0.67      0.72       132
#
# Error in evaluation: 'auc'
#
# Step 8: Model Interpretation and Clinical Insights...
# ==================================================
# CLINICAL INSIGHTS:
# ==================================================
# 1. The model predicts mortality risk based on sequential patient data
# 2. Key predictive features include adverse events and treatment patterns
# 3. Model performance indicates good discriminative ability (AUC > 0.7)
# 4. Optimal threshold balancing sensitivity and specificity
# 5. Can be used for early identification of high-risk patients
